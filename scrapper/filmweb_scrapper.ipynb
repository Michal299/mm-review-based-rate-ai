# %%
import requests as rq
from urllib.parse import urljoin
import pandas as pd
import tqdm
from urllib.parse import quote
from bs4 import BeautifulSoup

# %%
URL = "https://www.filmweb.pl"

# %%
class FilmwebClient:
    def __init__(self, server) -> None:
        self.server = server
        self.common_headers = {'x-locale': 'en'}
        self.users = []
        self.critics = []
        self.movies = []
        self.proxy = {
            'http': '162.55.95.91:2289',
            'http': '162.55.95.91:3857',
            'http': '217.182.170.224:80'
        }


    def search_movies(self, page: int):
        url = urljoin(self.server, f'/api/v1/films/search?page={page}')
        return rq.get(url, headers=self.common_headers)


    def get_critics(self):
        url = urljoin(self.server, '/api/v1/film/critics')
        return rq.get(url, headers=self.common_headers)
    

    def get_movie_rating(self, movie_id):
        url = urljoin(self.server, f'/api/v1/film/{movie_id}/rating')
        return rq.get(url, headers=self.common_headers)
    

    def get_movie_critics(self, movie_id):
        url = urljoin(self.server, f'/api/v1/film/{movie_id}/critics')
        return rq.get(url, headers=self.common_headers)
    

    def get_movie_review(self, movie_id, critic_username):
        url = urljoin(self.server, f'/api/v1/user/{critic_username}/vote/film/{movie_id}')
        return rq.get(url, headers=self.common_headers)


    def get_reviewed_movies(self, critic_username):
        url = urljoin(self.server, f'/api/v1/user/{critic_username}/vote/film/')
        return rq.get(url, headers=self.common_headers)
    

    def get_reviewed_servies(self, critic_username):
        url = urljoin(self.server, f'/api/v1/user/{critic_username}/vote/serial')
        return rq.get(url, headers=self.common_headers)
    
    
    def get_tv_series_review(self, series_id, critic_username):
        url = urljoin(self.server, f'/api/v1/user/{critic_username}/vote/serial/{series_id}')
        return rq.get(url, headers=self.common_headers)
    

    def get_title(self, id):
        url = urljoin(self.server, f'/api/v1/title/{id}/info')
        return rq.get(url, headers=self.common_headers, timeout=(3, 5), proxies=self.proxy)
    
    
    def get_movie_info(self, title):
        url = urljoin(self.server, f'/api/v1/film/{title}/info')
        return rq.get(url, headers=self.common_headers, timeout=(3, 5), proxies=self.proxy)
    
    def get_movie_discussion(self, movie_path, page=1):
        url = urljoin(self.server, f'/film/{movie_path}/discussion?plusMinus=true&page={page}')
        return rq.get(url, headers=self.common_headers, timeout=(3, 5), proxies=self.proxy)

# %%
filmweb = FilmwebClient(URL)

# %% [markdown]
# # Get movies

# %%
def generator():
  while True:
    yield


page = 1
movies = []
for _ in tqdm.tqdm(generator()):
    response = filmweb.search_movies(page)
    if response.status_code != 200:
        print(f'Reached the end of movies list, last page: {page-1}, number of movies: {len(movies)}')
        break
    try:
        movies += response.json()['searchHits']
    except:
        print(f'Cannot parse movies from page {page}.')
    page+=1

# %% [markdown]
# Don't worry about above problem as long as the number of pages is reasonable.

# %%
df_movies = pd.DataFrame(movies)
df_movies.head()
# Out:
#      id  type
# 0   862  film
# 1  1048  film
# 2   998  film
# 3   671  film
# 4  9136  film

# %%
df_movies.count()
# Out:
# id      4630
# type    4630
# dtype: int64

# %% [markdown]
# Save so far collected data, just in case

# %%
df_movies[['id', 'type']].to_csv('intermidate/movies.csv', index=False)

# %% [markdown]
# # Get critics

# %%
df_critics = pd.DataFrame(filmweb.get_critics().json())
df_critics.head()
# Out:
#         id            userName  priority                        publisher
# 0  1164541     michaloleszczyk         1           Spoiler Master Podcast
# 1  1243927                tru3         1                      Magazyn SFP
# 2  1418184         Cateborough         1  POPcast - podcast o popkulturze
# 3  1589044         darek_arest         1                krytyk niezależny
# 4  3281021  smolinskisebastian         1                krytyk niezależny

# %%
df_critics.groupby('priority').count()
# Out:
#           id  userName  publisher
# priority
# 1          9         9          9
# 2         10        10         10
# 3         13        13         13
# 4         17        17         17
# 5          7         7          7
# 6         10        10         10
# 7          1         1          1

# %%
df_critics.count()
# Out:
# id           67
# userName     67
# priority     67
# publisher    67
# dtype: int64

# %%
df_critics.to_csv('intermidate/critics.csv', index=False)

# %% [markdown]
# # Dataset preparation
# Iterate over critics and get movies which they reviewed

# %%
results = []
critics = df_critics['userName'].values.tolist()

# %%
it = 0
while len(results) < len(df_critics['userName']):
    for critic in tqdm.tqdm(critics[it:]):
        try:
            movies_ids = list(map(lambda response: {'username': critic, 'movie_id': response[0]}, filmweb.get_reviewed_movies(critic).json()))
            results += movies_ids
        except Exception as e:
            print(f'Exception when getting {critic}\'s reviews. {e}')
            break
        it+=1
# Out:
# 100%|██████████| 67/67 [00:10<00:00,  6.37it/s]

# %%
df_critics_reviews = pd.DataFrame(results)
df_critics_reviews.head()
# Out:
#           username  movie_id
# 0  michaloleszczyk  10014103
# 1  michaloleszczyk  10025735
# 2  michaloleszczyk    805204
# 3  michaloleszczyk    877700
# 4  michaloleszczyk  10026692

# %%
for i in tqdm.tqdm(df_critics_reviews.values[2000:]):
    pass
# Out:
# 100%|██████████| 4324/4324 [00:00<00:00, 3106040.50it/s]

# %%
it = 0
results = []
while len(results) < len(df_critics_reviews.values) or it >= len(df_critics_reviews.values):
    for case in tqdm.tqdm(df_critics_reviews.values[it:]):
        try:
            response = filmweb.get_movie_review(critic_username=case[0], movie_id=case[1]).json()
            if 'comment' in response:
                movie_rating = filmweb.get_movie_rating(case[1]).json()
                results.append({'username': case[0], 
                                'movie_id': case[1],
                                'user_rate': response['rate'],
                                'user_comment': response['comment'],
                                'movie_rating': movie_rating['rate'],
                                'movie_rating_count': movie_rating['count']
                                })
        except Exception as e:
            print(f'Fetching data about movie rating failed: {e}')
            break
        it+=1
# Out:
#   3%|▎         | 165/6324 [03:00<1:52:10,  1.09s/it]
# Fetching data about movie rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/tru3/vote/film/10019460 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fc2157464a0>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   5%|▍         | 295/6159 [04:09<1:22:46,  1.18it/s]
# Fetching data about movie rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/film/164870/rating (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fc215745db0>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   3%|▎         | 176/5864 [02:45<1:29:21,  1.06it/s]
# Fetching data about movie rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/film/10004934/rating (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fc215745b10>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   5%|▌         | 312/5688 [04:22<1:15:16,  1.19it/s]
# Fetching data about movie rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/film/10004934/rating (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fc215745b70>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   1%|          | 39/5376 [02:19<5:17:37,  3.57s/it]
# Fetching data about movie rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/film/754800/rating (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fc215746440>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   9%|▉         | 501/5337 [04:10<40:15,  2.00it/s]
# Fetching data about movie rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/sergiuszowo11/vote/film/10013518 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fc215745f30>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   7%|▋         | 316/4836 [04:34<1:05:25,  1.15it/s]
# Fetching data about movie rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/Jakub_Demianczuk/vote/film/36469 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fc215744b50>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   3%|▎         | 151/4520 [02:56<1:24:55,  1.17s/it]
# Fetching data about movie rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/film/10020414/rating (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7fc215745c90>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   1%|▏         | 65/4369 [02:25<2:40:27,  2.24s/it]
# Fetching data about movie rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/
#
# File ~/School/Sem9/mm-review-based-rate-ai/.venv/lib/python3.10/site-packages/tqdm/std.py:1099, in tqdm.__init__(self, iterable, desc, total, leave, file, ncols, mininterval, maxinterval, miniters, ascii, disable, unit, unit_scale, dynamic_ncols, smoothing, bar_format, initial, position, postfix, unit_divisor, write_bytes, lock_args, nrows, colour, delay, gui, **kwargs)
#    1097     self.sp = self.status_printer(self.fp)
#    1098     if delay <= 0:
# -> 1099         self.refresh(lock_args=self.lock_args)
#    1101 # Init the time counter
#    1102 self.last_print_t = self._time()
#
# File ~/School/Sem9/mm-review-based-rate-ai/.venv/lib/python3.10/site-packages/tqdm/std.py:1348, in tqdm.refresh(self, nolock, lock_args)
#    1346     else:
#    1347         self._lock.acquire()
# -> 1348 self.display()
#    1349 if not nolock:
#    1350     self._lock.release()
#
# File ~/School/Sem9/mm-review-based-rate-ai/.venv/lib/python3.10/site-packages/tqdm/std.py:1496, in tqdm.display(self, msg, pos)
#    1494 if pos:
#    1495     self.moveto(pos)
# -> 1496 self.sp(self.__str__() if msg is None else msg)
#    1497 if pos:
#    1498     self.moveto(-pos)
#
# File ~/School/Sem9/mm-review-based-rate-ai/.venv/lib/python3.10/site-packages/tqdm/std.py:462, in tqdm.status_printer.<locals>.print_status(s)
#     460 def print_status(s):
#     461     len_s = disp_len(s)
# --> 462     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     463     last_len[0] = len_s
#
# File ~/School/Sem9/mm-review-based-rate-ai/.venv/lib/python3.10/site-packages/tqdm/std.py:456, in tqdm.status_printer.<locals>.fp_write(s)
#     454 def fp_write(s):
#     455     fp.write(str(s))
# --> 456     fp_flush()
#
# File ~/School/Sem9/mm-review-based-rate-ai/.venv/lib/python3.10/site-packages/tqdm/utils.py:195, in DisableOnWriteError.disable_on_exception.<locals>.inner(*args, **kwargs)
#     193 def inner(*args, **kwargs):
#     194     try:
# --> 195         return func(*args, **kwargs)
#     196     except OSError as e:
#     197         if e.errno != 5:
#
# File ~/School/Sem9/mm-review-based-rate-ai/.venv/lib/python3.10/site-packages/ipykernel/iostream.py:580, in OutStream.flush(self)
#     578     self.pub_thread.schedule(evt.set)
#     579     # and give a timeout to avoid
# --> 580     if not evt.wait(self.flush_timeout):
#     581         # write directly to __stderr__ instead of warning because
#     582         # if this is happening sys.stderr may be the problem.
#     583         print("IOStream.flush timed out", file=sys.__stderr__)
#     584 else:
#
# File /usr/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /usr/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
ds_df = pd.DataFrame(results)
ds_df.head()
# Out:
#           username  movie_id  user_rate  \
# 0  michaloleszczyk  10014103          8
# 1  michaloleszczyk  10025735          3
# 2  michaloleszczyk    805204          9
# 3  michaloleszczyk  10034333          9
# 4  michaloleszczyk  10015490          9
#
#                                         user_comment  movie_rating  \
# 0  Willa Hössa jako makieta najciemniejszej stron...       8.32095
# 1  Zgentryfikowana "Mama i dziwka" o smaku pumpki...       6.41777
# 2  "Ile wilków widzisz na obrazku?" A ile widzisz...       7.41684
# 3  Film bliski perfekcji; czysty i syty jak ronde...       7.36086
# 4  Wielka niespodzianka i najbardziej oryginalny ...       5.44533
#
#    movie_rating_count
# 0                 296
# 1                 833
# 2                9884
# 3                 557
# 4                 375

# %%
ds_df.count()
# Out:
# username              3057
# movie_id              3057
# user_rate             3057
# user_comment          3057
# movie_rating          3057
# movie_rating_count    3057
# dtype: int64

# %%
ds_df.to_json('../dataset/dataset_movies.json')

# %%
ds_df.to_csv('../dataset/dataset_movies.csv', index=False, sep='$', encoding='utf8')

# %% [markdown]
# TODO: fetch tv series analogously to movies
# DO NOT MERGE THE DATASETS! We may consider if we want to train model only on movies, tv series or both
# # TV series

# %%
df_critics = pd.read_csv('intermidate/critics.csv')
df_critics.head()
# Out:
#    Unnamed: 0       id            userName  priority  \
# 0           0  1164541     michaloleszczyk         1
# 1           1  1243927                tru3         1
# 2           2  1418184         Cateborough         1
# 3           3  1589044         darek_arest         1
# 4           4  3281021  smolinskisebastian         1
#
#                          publisher
# 0           Spoiler Master Podcast
# 1                      Magazyn SFP
# 2  POPcast - podcast o popkulturze
# 3                krytyk niezależny
# 4                krytyk niezależny

# %%
result = []
for critic in tqdm.tqdm(df_critics['userName']):
    response = filmweb.get_reviewed_servies(critic).json()
    result += list(map(lambda review: {'username':critic, 'series_id':review[0]}, response))
df_critics_reviews_series = pd.DataFrame(result)
df_critics_reviews_series.head()
# Out:
# 100%|██████████| 67/67 [00:11<00:00,  5.79it/s]
#           username  series_id
# 0  michaloleszczyk      94606
# 1  michaloleszczyk     867132
# 2  michaloleszczyk     868514
# 3  michaloleszczyk     876630
# 4  michaloleszczyk     862322

# %%
it = 0
results = []
while len(results) < len(df_critics_reviews_series.values):
    for case in tqdm.tqdm(df_critics_reviews_series.values[it:]):
        try:
            response = filmweb.get_tv_series_review(critic_username=case[0], series_id=case[1]).json()
            if 'comment' in response:
                series_rating = filmweb.get_movie_rating(case[1]).json()
                results.append({'username': case[0], 
                                'series_id': case[1],
                                'user_rate': response['rate'],
                                'user_comment': response['comment'],
                                'series_rating': series_rating['rate'],
                                'series_rating_count': series_rating['count']
                                })
        except Exception as e:
            print(f'Fetching data about tv series rating failed: {e}')
            break
        it+=1
    if it >= len(df_critics_reviews_series.values):
        break
# Out:
#   7%|▋         | 262/3734 [03:08<41:35,  1.39it/s]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/makina13/vote/serial/843886 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f603320fc40>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   9%|▉         | 329/3472 [04:30<43:02,  1.22it/s]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/ksiawcik_13/vote/serial/809555 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f60329545e0>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   2%|▏         | 73/3143 [02:25<1:41:54,  1.99s/it]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/film/750359/rating (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f6032954a60>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   5%|▍         | 145/3070 [02:39<53:42,  1.10s/it]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/Igi3/vote/serial/746188 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f6032954b20>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   3%|▎         | 79/2925 [02:27<1:28:31,  1.87s/it]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/Cinestetyk/vote/serial/809758 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f6032954a30>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   9%|▉         | 261/2846 [03:10<31:26,  1.37it/s]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/bartosz_czartoryski/vote/serial/10011822 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f60329544c0>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#  10%|▉         | 252/2585 [04:18<39:48,  1.02s/it]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/GrzegorzLaguna/vote/serial/646514 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f6032955870>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   7%|▋         | 167/2333 [02:43<35:24,  1.02it/s]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/film/832704/rating (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f6032955db0>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   6%|▌         | 133/2166 [02:49<43:18,  1.28s/it]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/no_face_no/vote/serial/876630 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f6032954dc0>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   6%|▋         | 128/2033 [02:39<39:37,  1.25s/it]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/Cosimo_Villa_Nova/vote/serial/801643 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f60333891b0>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#  19%|█▉        | 360/1905 [04:46<20:30,  1.26it/s]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/olberlin/vote/serial/87721 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f60329544f0>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   0%|          | 0/1545 [02:11<?, ?it/s]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/olberlin/vote/serial/87721 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f6032955540>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#  22%|██▏       | 344/1545 [03:39<12:45,  1.57it/s]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/Tutaj_17/vote/serial/10005323 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f60329551e0>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#   1%|          | 10/1201 [02:13<4:24:13, 13.31s/it]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/film/868116/rating (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f6032954130>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#  25%|██▌       | 302/1191 [03:10<09:20,  1.59it/s]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/jultacz/vote/serial/848385 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f60329549a0>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#  20%|██        | 180/889 [03:49<15:03,  1.27s/it]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/EvvLe/vote/serial/875799 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f60329542e0>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#  19%|█▉        | 135/709 [02:39<11:19,  1.18s/it]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/film/793789/rating (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f6032955720>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#  27%|██▋       | 154/574 [02:45<07:32,  1.08s/it]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/mwol/vote/serial/99424 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f6032955990>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
#  77%|███████▋  | 322/420 [03:35<01:05,  1.50it/s]
# Fetching data about tv series rating failed: HTTPSConnectionPool(host='www.filmweb.pl', port=443): Max retries exceeded with url: /api/v1/user/dem3000/vote/serial/654010 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f6032955c60>, 'Connection to www.filmweb.pl timed out. (connect timeout=None)'))
# 100%|██████████| 98/98 [00:28<00:00,  3.50it/s]

# %%
ds_df = pd.DataFrame(results)
ds_df.head()
# Out:
#           username  series_id  user_rate  \
# 0  michaloleszczyk     867132          8
# 1  michaloleszczyk     862322         10
# 2  michaloleszczyk     819951          7
# 3             tru3   10011884          8
# 4             tru3     860894          5
#
#                                         user_comment  series_rating  \
# 0  NH. Grand finale mock-satanistycznej komedii V...        7.57339
# 1  Koronkowe komiczne eseje dokumentalne o urokac...        8.27645
# 2  Znakomicie zrealizowany serial, którego ostatn...        7.85234
# 3  Ale to jest dobre! Absolutnie zaskakujący seri...        7.62731
# 4  Serial pozerski. Główny bohater - Czuły (Borys...        6.07103
#
#    series_rating_count
# 0                  436
# 1                 4178
# 2                10409
# 3                 7199
# 4                 4885

# %%
ds_df.to_json('../dataset/dataset_tv_series.json')
ds_df.to_csv('../dataset/dataset_tv_series.csv', sep='$', encoding='utf-8')

# %% [markdown]
# # Datasets merge

# %%
df_movies = pd.read_csv('../dataset/dataset_movies.csv', encoding='utf-8', sep='$')
df_tv_series = pd.read_csv('../dataset/dataset_series2.csv', encoding='utf-8', sep='$')

# %%
df_movies = df_movies.rename(axis='columns', mapper={'movie_id': 'show_id', 
                                                     'movie_rating': 'show_rating', 
                                                     'movie_rating_count': 'show_rating_count'})
df_movies.head()
# Out:
#           username   show_id  user_rate  \
# 0  michaloleszczyk  10014103          8
# 1  michaloleszczyk  10025735          3
# 2  michaloleszczyk    805204          9
# 3  michaloleszczyk  10034333          9
# 4  michaloleszczyk  10015490          9
#
#                                         user_comment  show_rating  \
# 0  Willa Hössa jako makieta najciemniejszej stron...      8.32095
# 1  Zgentryfikowana "Mama i dziwka" o smaku pumpki...      6.41777
# 2  "Ile wilków widzisz na obrazku?" A ile widzisz...      7.41684
# 3  Film bliski perfekcji; czysty i syty jak ronde...      7.36086
# 4  Wielka niespodzianka i najbardziej oryginalny ...      5.44533
#
#    show_rating_count
# 0                296
# 1                833
# 2               9884
# 3                557
# 4                375

# %%
df_tv_series = df_tv_series.rename(axis='columns', mapper={'series_id': 'show_id', 
                                                           'series_rating': 'show_rating', 
                                                           'series_rating_count': 'show_rating_count'})
df_tv_series.head()
# Out:
#           username   show_id  user_rate  \
# 0  michaloleszczyk    867132          8
# 1  michaloleszczyk    862322         10
# 2  michaloleszczyk    819951          7
# 3             tru3  10011884          8
# 4             tru3    860894          5
#
#                                         user_comment  show_rating  \
# 0  NH. Grand finale mock-satanistycznej komedii V...      7.57339
# 1  Koronkowe komiczne eseje dokumentalne o urokac...      8.27645
# 2  Znakomicie zrealizowany serial, którego ostatn...      7.85234
# 3  Ale to jest dobre! Absolutnie zaskakujący seri...      7.62731
# 4  Serial pozerski. Główny bohater - Czuły (Borys...      6.07103
#
#    show_rating_count
# 0                436
# 1               4178
# 2              10409
# 3               7199
# 4               4885

# %%
df_movies['type'] = 'movie'
df_tv_series['type'] = 'tv_series'

# %%
df_dataset = pd.concat([df_movies, df_tv_series], axis=0)
df_dataset
# Out:
#              username   show_id  user_rate  \
# 0     michaloleszczyk  10014103          8
# 1     michaloleszczyk  10025735          3
# 2     michaloleszczyk    805204          9
# 3     michaloleszczyk  10034333          9
# 4     michaloleszczyk  10015490          9
# ...               ...       ...        ...
# 1326       alekhudzik    849662          3
# 1327       alekhudzik  10012801          6
# 1328       alekhudzik    875491          7
# 1329       alekhudzik    877025         10
# 1330       alekhudzik    835082         10
#
#                                            user_comment  show_rating  \
# 0     Willa Hössa jako makieta najciemniejszej stron...      8.32095
# 1     Zgentryfikowana "Mama i dziwka" o smaku pumpki...      6.41777
# 2     "Ile wilków widzisz na obrazku?" A ile widzisz...      7.41684
# 3     Film bliski perfekcji; czysty i syty jak ronde...      7.36086
# 4     Wielka niespodzianka i najbardziej oryginalny ...      5.44533
# ...                                                 ...          ...
# 1326  O wow. Nie udało się zekranizować gry komputer...      7.77990
# 1327  No takie ten. "1 świat 3 świat", kalejdoskop p...      6.79320
# 1328        Dwójka lepsza od jedynki. Zamykamy dyskusję      7.67484
# 1329  Jest to najlepszy serial "Coming of age" świat...      7.22280
# 1330  LEPSZE OD PETERA JACKSONA bo a) więcej kasy b)...      5.19931
#
#       show_rating_count       type
# 0                   296      movie
# 1                   833      movie
# 2                  9884      movie
# 3                   557      movie
# 4                   375      movie
# ...                 ...        ...
# 1326              58245  tv_series
# 1327                353  tv_series
# 1328              40515  tv_series
# 1329                579  tv_series
# 1330              28057  tv_series
#
# [4388 rows x 7 columns]

# %%
df_dataset = df_dataset.reset_index(drop=True)

# %%
df_dataset.to_csv('../dataset/dataset.csv', encoding='utf-8', sep='$', index=False)
df_dataset.to_json('../dataset/dataset.json')

# %% [markdown]
# # Dataset cleanup
# Filter out empty comments

# %%
df_dataset = pd.read_csv('../dataset/dataset.csv', sep='$', encoding='utf-8')
df_dataset
# Out:
#              username   show_id  user_rate  \
# 0     michaloleszczyk  10014103          8
# 1     michaloleszczyk  10025735          3
# 2     michaloleszczyk    805204          9
# 3     michaloleszczyk  10034333          9
# 4     michaloleszczyk  10015490          9
# ...               ...       ...        ...
# 4383       alekhudzik    849662          3
# 4384       alekhudzik  10012801          6
# 4385       alekhudzik    875491          7
# 4386       alekhudzik    877025         10
# 4387       alekhudzik    835082         10
#
#                                            user_comment  show_rating  \
# 0     Willa Hössa jako makieta najciemniejszej stron...      8.32095
# 1     Zgentryfikowana "Mama i dziwka" o smaku pumpki...      6.41777
# 2     "Ile wilków widzisz na obrazku?" A ile widzisz...      7.41684
# 3     Film bliski perfekcji; czysty i syty jak ronde...      7.36086
# 4     Wielka niespodzianka i najbardziej oryginalny ...      5.44533
# ...                                                 ...          ...
# 4383  O wow. Nie udało się zekranizować gry komputer...      7.77990
# 4384  No takie ten. "1 świat 3 świat", kalejdoskop p...      6.79320
# 4385        Dwójka lepsza od jedynki. Zamykamy dyskusję      7.67484
# 4386  Jest to najlepszy serial "Coming of age" świat...      7.22280
# 4387  LEPSZE OD PETERA JACKSONA bo a) więcej kasy b)...      5.19931
#
#       show_rating_count       type
# 0                   296      movie
# 1                   833      movie
# 2                  9884      movie
# 3                   557      movie
# 4                   375      movie
# ...                 ...        ...
# 4383              58245  tv_series
# 4384                353  tv_series
# 4385              40515  tv_series
# 4386                579  tv_series
# 4387              28057  tv_series
#
# [4388 rows x 7 columns]

# %%
df_dataset = df_dataset[~df_dataset['user_comment'].isna()].reset_index(drop=True)
df_dataset = df_dataset[df_dataset['user_comment'].str.len() > 3].reset_index(drop=True)
df_dataset
# Out:
#              username   show_id  user_rate  \
# 0     michaloleszczyk  10014103          8
# 1     michaloleszczyk  10025735          3
# 2     michaloleszczyk    805204          9
# 3     michaloleszczyk  10034333          9
# 4     michaloleszczyk  10015490          9
# ...               ...       ...        ...
# 4276       alekhudzik    849662          3
# 4277       alekhudzik  10012801          6
# 4278       alekhudzik    875491          7
# 4279       alekhudzik    877025         10
# 4280       alekhudzik    835082         10
#
#                                            user_comment  show_rating  \
# 0     Willa Hössa jako makieta najciemniejszej stron...      8.32095
# 1     Zgentryfikowana "Mama i dziwka" o smaku pumpki...      6.41777
# 2     "Ile wilków widzisz na obrazku?" A ile widzisz...      7.41684
# 3     Film bliski perfekcji; czysty i syty jak ronde...      7.36086
# 4     Wielka niespodzianka i najbardziej oryginalny ...      5.44533
# ...                                                 ...          ...
# 4276  O wow. Nie udało się zekranizować gry komputer...      7.77990
# 4277  No takie ten. "1 świat 3 świat", kalejdoskop p...      6.79320
# 4278        Dwójka lepsza od jedynki. Zamykamy dyskusję      7.67484
# 4279  Jest to najlepszy serial "Coming of age" świat...      7.22280
# 4280  LEPSZE OD PETERA JACKSONA bo a) więcej kasy b)...      5.19931
#
#       show_rating_count       type
# 0                   296      movie
# 1                   833      movie
# 2                  9884      movie
# 3                   557      movie
# 4                   375      movie
# ...                 ...        ...
# 4276              58245  tv_series
# 4277                353  tv_series
# 4278              40515  tv_series
# 4279                579  tv_series
# 4280              28057  tv_series
#
# [4281 rows x 7 columns]

# %%
df_dataset.to_csv('../dataset/dataset.csv', encoding='utf-8', sep='$', index=False)
df_dataset.to_json('../dataset/dataset.json')

# %% [markdown]
# # Extend dataset with movie/series name

# %%
df_dataset = pd.read_csv('../dataset/dataset.csv', encoding='utf-8', sep='$')
df_dataset
# Out:
#              username   show_id  user_rate  \
# 0     michaloleszczyk  10014103          8
# 1     michaloleszczyk  10025735          3
# 2     michaloleszczyk    805204          9
# 3     michaloleszczyk  10034333          9
# 4     michaloleszczyk  10015490          9
# ...               ...       ...        ...
# 4276       alekhudzik    849662          3
# 4277       alekhudzik  10012801          6
# 4278       alekhudzik    875491          7
# 4279       alekhudzik    877025         10
# 4280       alekhudzik    835082         10
#
#                                            user_comment  show_rating  \
# 0     Willa Hössa jako makieta najciemniejszej stron...      8.32095
# 1     Zgentryfikowana "Mama i dziwka" o smaku pumpki...      6.41777
# 2     "Ile wilków widzisz na obrazku?" A ile widzisz...      7.41684
# 3     Film bliski perfekcji; czysty i syty jak ronde...      7.36086
# 4     Wielka niespodzianka i najbardziej oryginalny ...      5.44533
# ...                                                 ...          ...
# 4276  O wow. Nie udało się zekranizować gry komputer...      7.77990
# 4277  No takie ten. "1 świat 3 świat", kalejdoskop p...      6.79320
# 4278        Dwójka lepsza od jedynki. Zamykamy dyskusję      7.67484
# 4279  Jest to najlepszy serial "Coming of age" świat...      7.22280
# 4280  LEPSZE OD PETERA JACKSONA bo a) więcej kasy b)...      5.19931
#
#       show_rating_count       type
# 0                   296      movie
# 1                   833      movie
# 2                  9884      movie
# 3                   557      movie
# 4                   375      movie
# ...                 ...        ...
# 4276              58245  tv_series
# 4277                353  tv_series
# 4278              40515  tv_series
# 4279                579  tv_series
# 4280              28057  tv_series
#
# [4281 rows x 7 columns]

# %%
def extend_with_title(id):
    response = filmweb.get_title(id)
    if response.status_code == 200:
        if 'originalTitle' not in response.json():
            title = response.json()['title']
        else:
            title = response.json()['originalTitle']
        print(f'{id} -> {response.json()}')
        return (id, title)
    else:
        print(f"Error: {response.status_code} -> {response.content}")
        return (id, None)

# %%
mapped = []

# %%
from time import sleep

input = df_dataset['show_id'].to_list()
counter = 173
while counter < len(input):
    print(f"{counter}/{len(input)}")
    try:
        elem = extend_with_title(input[counter])
        counter += 1
        mapped.append(elem)
    except:
        print(f"Failed for: {input[counter]}. Try again in second.")
        sleep(1)
    sleep(0.2)
# Out:
# 173/4281
# 10033068 -> {'title': 'Soulcatcher', 'originalTitle': 'Operacja: Soulcatcher', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/30/68/10033068/8080804.$.jpg'}
# 174/4281
# 99390 -> {'title': 'Love Actually Is All Around', 'originalTitle': 'Love Actually', 'year': 2003, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/93/90/99390/7906420.$.jpg'}
# 175/4281
# 10011888 -> {'title': "Mother's Day", 'originalTitle': 'Dzień Matki', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/18/88/10011888/8087448.$.jpg'}
# 176/4281
# 857111 -> {'title': 'Swarm', 'originalTitle': 'Rój', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/71/11/857111/8064206.$.jpg'}
# 177/4281
# 877030 -> {'title': 'Fanfic', 'originalTitle': 'Fanfik', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/70/30/877030/8068572.$.jpg'}
# 178/4281
# 10011964 -> {'title': 'Sick of Myself', 'originalTitle': 'Syk pike', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/64/10011964/8102580.$.jpg'}
# 179/4281
# 857962 -> {'title': 'The Peasants', 'originalTitle': 'Chłopi', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/79/62/857962/8107908.$.jpg'}
# 180/4281
# 805204 -> {'title': 'Killers of the Flower Moon', 'originalTitle': 'Killers of the Flower Moon', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/52/04/805204/8088427.$.jpg'}
# 181/4281
# 10031530 -> {'title': 'Perpetrator', 'originalTitle': 'Perpetrator', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/15/30/10031530/8081531.$.jpg'}
# 182/4281
# 10032677 -> {'title': 'Fallen Leaves', 'originalTitle': 'Kuolleet lehdet', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/26/77/10032677/8095694.$.jpg'}
# 183/4281
# 10025735 -> {'title': 'Passages', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/57/35/10025735/8087169.$.jpg'}
# 184/4281
# 10039040 -> {'title': 'The Green Border', 'originalTitle': 'Zielona granica', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/90/40/10039040/8102370.$.jpg'}
# 185/4281
# 872645 -> {'title': 'Imago', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/26/45/872645/8077944.$.jpg'}
# 186/4281
# 10028825 -> {'title': 'Ukryta sieć', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/88/25/10028825/8078773.$.jpg'}
# 187/4281
# 10026113 -> {'title': 'Reality', 'originalTitle': 'Reality', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/61/13/10026113/8072664.$.jpg'}
# 188/4281
# 10026657 -> {'title': 'Talk to Me', 'originalTitle': 'Talk to Me', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/66/57/10026657/8079379.$.jpg'}
# 189/4281
# 878158 -> {'title': 'Asteroid City', 'originalTitle': 'Asteroid City', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/81/58/878158/8071093.$.jpg'}
# 190/4281
# 10015819 -> {'title': 'Medusa Deluxe', 'originalTitle': 'Medusa Deluxe', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/58/19/10015819/8086172.$.jpg'}
# 191/4281
# 874369 -> {'title': 'The Eternal Daughter', 'originalTitle': 'The Eternal Daughter', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/43/69/874369/8046510.$.jpg'}
# 192/4281
# 10013187 -> {'title': 'The Five Devils', 'originalTitle': 'Les cinq diables', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/31/87/10013187/8082281.$.jpg'}
# 193/4281
# 10006328 -> {'title': 'The Cow that Sang a Song About the Future', 'originalTitle': 'La vaca que cantó una canción sobre el futuro', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/63/28/10006328/8072645.$.jpg'}
# 194/4281
# 10029379 -> {'title': 'Polite Society', 'originalTitle': 'Polite Society', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/93/79/10029379/8059186.$.jpg'}
# 195/4281
# 10020866 -> {'title': 'They Cloned Tyrone', 'originalTitle': 'They Cloned Tyrone', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/08/66/10020866/8075573.$.jpg'}
# 196/4281
# 832304 -> {'title': 'Mission: Impossible - Dead Reckoning - Part One', 'originalTitle': 'Mission: Impossible - Dead Reckoning - Part One', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/23/04/832304/8075944.$.jpg'}
# 197/4281
# 10031406 -> {'title': 'Femme', 'originalTitle': 'Femme', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/14/06/10031406/8059498.$.jpg'}
# 198/4281
# 10031611 -> {'title': 'Scrapper', 'originalTitle': 'Scrapper', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/16/11/10031611/8089854.$.jpg'}
# 199/4281
# 10029803 -> {'title': 'Past Lives', 'originalTitle': 'Past Lives', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/98/03/10029803/8094509.$.jpg'}
# 200/4281
# 853834 -> {'title': 'Triangle of Sadness', 'originalTitle': 'Triangle of Sadness', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/38/34/853834/8042146.$.jpg'}
# 201/4281
# 754800 -> {'title': 'Barbie', 'originalTitle': 'Barbie', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/48/00/754800/8082153.$.jpg'}
# 202/4281
# 10034186 -> {'title': 'Kidnapped', 'originalTitle': 'Rapito', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/41/86/10034186/8071339.$.jpg'}
# 203/4281
# 10029801 -> {'title': 'Orlando, My Political Biography', 'originalTitle': 'Orlando, ma biographie politique', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/98/01/10029801/8096693.$.jpg'}
# 204/4281
# 875647 -> {'title': 'The Menu ', 'originalTitle': 'The Menu ', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/56/47/875647/8053539.$.jpg'}
# 205/4281
# 10034331 -> {'title': 'How to Have Sex', 'originalTitle': 'How to Have Sex', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/43/31/10034331/8095519.$.jpg'}
# 206/4281
# 10026114 -> {'title': 'Silver Haze', 'originalTitle': 'Silver Haze', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/61/14/10026114/8050271.$.jpg'}
# 207/4281
# 10019146 -> {'title': 'Blue Jean', 'originalTitle': 'Blue Jean', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/91/46/10019146/8094457.$.jpg'}
# 208/4281
# 806077 -> {'title': 'Guardians of the Galaxy Vol. 3', 'originalTitle': 'Guardians of the Galaxy Vol. 3', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/60/77/806077/8061365.$.jpg'}
# 209/4281
# 527837 -> {'title': 'Indiana Jones 5', 'originalTitle': 'Indiana Jones and the Dial of Destiny', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/78/37/527837/8072665.$.jpg'}
# 210/4281
# 10004934 -> {'title': 'She Said', 'originalTitle': 'She Said', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/49/34/10004934/8022151.$.jpg'}
# 211/4281
# 10016728 -> {'title': 'All the Beauty and the Bloodshed', 'originalTitle': 'All the Beauty and the Bloodshed', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/67/28/10016728/8034519.$.jpg'}
# 212/4281
# 10017590 -> {'title': 'How Sad, How Lovely', 'originalTitle': 'Roving Woman', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/75/90/10017590/8064259.$.jpg'}
# 213/4281
# 10008865 -> {'title': 'The Quiet Girl', 'originalTitle': 'An Cailín Ciúin', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/88/65/10008865/8047035.$.jpg'}
# 214/4281
# 10025744 -> {'title': 'Pianoforte', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/57/44/10025744/8096121.$.jpg'}
# 215/4281
# 10019378 -> {'title': 'Norwegian Dream', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/93/78/10019378/8067247.$.jpg'}
# 216/4281
# 10014388 -> {'title': 'Women Talking', 'originalTitle': 'Women Talking', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/43/88/10014388/8028691.$.jpg'}
# 217/4281
# 10026510 -> {'title': 'Rye Lane', 'originalTitle': 'Rye Lane', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/65/10/10026510/8063485.$.jpg'}
# 218/4281
# 10006435 -> {'title': 'Nanny', 'originalTitle': 'Nanny', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/64/35/10006435/8029053.$.jpg'}
# 219/4281
# 876242 -> {'title': 'Glass Onion: A Knives Out Mystery', 'originalTitle': 'Glass Onion: A Knives Out Mystery', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/62/42/876242/8038799.$.jpg'}
# 220/4281
# 10016709 -> {'title': 'Tár', 'originalTitle': 'Tár', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/67/09/10016709/8069974.$.jpg'}
# 221/4281
# 181137 -> {'title': 'Titane', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/11/37/181137/7975064.$.jpg'}
# 222/4281
# 875490 -> {'title': 'Drive My Car', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/54/90/875490/8047508.$.jpg'}
# 223/4281
# 850352 -> {'title': "C'mon C'mon", 'originalTitle': "C'mon C'mon", 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/03/52/850352/8004086.$.jpg'}
# 224/4281
# 10012484 -> {'title': 'The Woman King', 'originalTitle': 'The Woman King', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/24/84/10012484/8028259.$.jpg'}
# 225/4281
# 862867 -> {'title': 'The Decision to Break Up', 'originalTitle': 'Heojil kyolshim', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/28/67/862867/8050365.$.jpg'}
# 226/4281
# 10010480 -> {'title': 'The Wonder', 'originalTitle': 'The Wonder', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/04/80/10010480/8032934.$.jpg'}
# 227/4281
# 10013971 -> {'title': 'The Immensity', 'originalTitle': "L'immensità", 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/39/71/10013971/8090640.$.jpg'}
# 228/4281
# 877252 -> {'title': 'Sundown', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/72/52/877252/7993549.$.jpg'}
# 229/4281
# 875575 -> {'title': 'Great Freedom', 'originalTitle': 'Große Freiheit', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/55/75/875575/7965703.$.jpg'}
# 230/4281
# 870351 -> {'title': 'Red Rocket', 'originalTitle': 'Red Rocket', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/03/51/870351/7978789.$.jpg'}
# 231/4281
# 866841 -> {'title': 'Turning Red', 'originalTitle': 'Turning Red', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/68/41/866841/8016387.$.jpg'}
# 232/4281
# 856775 -> {'title': 'Official Competition', 'originalTitle': 'Competencia oficial', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/67/75/856775/8085021.$.jpg'}
# 233/4281
# 873373 -> {'title': 'Crimes of the Future', 'originalTitle': 'Crimes of the Future', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/33/73/873373/8040900.$.jpg'}
# 234/4281
# 10011953 -> {'title': 'EO', 'originalTitle': 'IO', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/53/10011953/8047437.$.jpg'}
# 235/4281
# 10012675 -> {'title': 'Elephant', 'originalTitle': 'Słoń', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/26/75/10012675/8024757.$.jpg'}
# 236/4281
# 10011944 -> {'title': 'Corsage', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/44/10011944/8053638.$.jpg'}
# 237/4281
# 10006285 -> {'title': 'Klondike', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/62/85/10006285/8002203.$.jpg'}
# 238/4281
# 10013507 -> {'title': 'Catherine Called Birdy', 'originalTitle': 'Catherine Called Birdy', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/35/07/10013507/8025661.$.jpg'}
# 239/4281
# 727844 -> {'title': 'The Lure', 'originalTitle': 'Córki dancingu', 'year': 2015, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/78/44/727844/7788499.$.jpg'}
# 240/4281
# 836119 -> {'title': 'Eternals', 'originalTitle': 'Eternals', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/61/19/836119/7983566.$.jpg'}
# 241/4281
# 10000816 -> {'title': 'Vera Dreams of the Sea', 'originalTitle': 'Vera andrron detin', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/08/16/10000816/7974463.$.jpg'}
# 242/4281
# 10012203 -> {'title': 'Looking for Venera', 'originalTitle': 'Në kërkim të Venerës', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/22/03/10012203/8018697.$.jpg'}
# 243/4281
# 863273 -> {'title': 'The Hill Where Lionesses Roar', 'originalTitle': 'Luaneshat e kodrës', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/32/73/863273/7965701.$.jpg'}
# 244/4281
# 10007593 -> {'title': 'Flux Gourmet', 'originalTitle': 'Flux Gourmet', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/75/93/10007593/8000531.$.jpg'}
# 245/4281
# 877300 -> {'title': 'Reflection', 'originalTitle': 'Vidblysk', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/73/00/877300/8004741.$.jpg'}
# 246/4281
# 849076 -> {'title': 'Exile', 'originalTitle': 'Exil', 'year': 2020, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/90/76/849076/7915628.$.jpg'}
# 247/4281
# 860180 -> {'title': 'Terrifier 2', 'originalTitle': 'Terrifier 2', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/01/80/860180/8056840.$.jpg'}
# 248/4281
# 660 -> {'title': 'Heat', 'originalTitle': 'Heat', 'year': 1995, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/06/60/660/7557726.$.jpg'}
# 249/4281
# 10019202 -> {'title': "The Pope's Exorcist", 'originalTitle': "The Pope's Exorcist", 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/92/02/10019202/8072959.$.jpg'}
# 250/4281
# 10041757 -> {'title': 'Poison', 'originalTitle': 'Poison', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/17/57/10041757/8093924.$.jpg'}
# 251/4281
# 875018 -> {'title': 'Dangerous Men', 'originalTitle': 'Niebezpieczni dżentelmeni', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/50/18/875018/8045254.$.jpg'}
# 252/4281
# 776171 -> {'title': 'Sicario: Day of the Soldado', 'originalTitle': 'Sicario: Day of the Soldado', 'year': 2018, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/61/71/776171/7853074.$.jpg'}
# 253/4281
# 875498 -> {'title': 'Roadrunner: A Film About Anthony Bourdain', 'originalTitle': 'Roadrunner: A Film About Anthony Bourdain', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/54/98/875498/7962641.$.jpg'}
# 254/4281
# 10026657 -> {'title': 'Talk to Me', 'originalTitle': 'Talk to Me', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/66/57/10026657/8079379.$.jpg'}
# 255/4281
# 399328 -> {'title': 'WALL·E', 'originalTitle': 'WALL·E', 'year': 2008, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/93/28/399328/7580343.$.jpg'}
# 256/4281
# 197782 -> {'title': 'The Music Room', 'originalTitle': 'Jalsaghar', 'year': 1958, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/77/82/197782/7951026.$.jpg'}
# 257/4281
# 93660 -> {'title': 'The Unvanquished', 'originalTitle': 'Aparajito', 'year': 1956, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/36/60/93660/7097669.$.jpg'}
# 258/4281
# 115926 -> {'title': 'The Hero', 'originalTitle': 'Nayak', 'year': 1966, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/59/26/115926/7588426.$.jpg'}
# 259/4281
# 115929 -> {'title': 'The Lonely Wife', 'originalTitle': 'Charulata', 'year': 1964, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/59/29/115929/7722515.$.jpg'}
# 260/4281
# 182521 -> {'title': 'Jeanne Dielman, 23 Quai du Commerce, 1080 Bruxelles', 'year': 1975, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/25/21/182521/7782327.$.jpg'}
# 261/4281
# 10031648 -> {'title': 'After', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/16/48/10031648/8059484.$.jpg'}
# 262/4281
# 10029801 -> {'title': 'Orlando, My Political Biography', 'originalTitle': 'Orlando, ma biographie politique', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/98/01/10029801/8096693.$.jpg'}
# 263/4281
# 93662 -> {'title': 'Pather Panchali', 'year': 1955, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/36/62/93662/7916608.$.jpg'}
# 264/4281
# 121115 -> {'title': 'Wake in Fright', 'year': 1971, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/11/15/121115/7485335.$.jpg'}
# 265/4281
# 10034333 -> {'title': 'The Passion of Dodin Bouffant', 'originalTitle': 'La passion de Dodin Bouffant', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/43/33/10034333/8105849.$.jpg'}
# 266/4281
# 754800 -> {'title': 'Barbie', 'originalTitle': 'Barbie', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/48/00/754800/8082153.$.jpg'}
# 267/4281
# 10024515 -> {'title': 'Inside', 'originalTitle': 'Inside', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/45/15/10024515/8054700.$.jpg'}
# 268/4281
# 874369 -> {'title': 'The Eternal Daughter', 'originalTitle': 'The Eternal Daughter', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/43/69/874369/8046510.$.jpg'}
# 269/4281
# 868880 -> {'title': 'Operation Fortune: Ruse de guerre', 'originalTitle': 'Operation Fortune: Ruse de guerre', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/88/80/868880/7987880.$.jpg'}
# 270/4281
# 10034267 -> {'title': 'Blood & Gold', 'originalTitle': 'Blut & Gold', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/42/67/10034267/8067243.$.jpg'}
# 271/4281
# 111954 -> {'title': 'Late Spring', 'originalTitle': 'Banshun', 'year': 1949, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/54/111954/7722147.$.jpg'}
# 272/4281
# 10014838 -> {'title': 'Hellraiser', 'originalTitle': 'Hellraiser', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/48/38/10014838/8032067.$.jpg'}
# 273/4281
# 10024845 -> {'title': 'The Year I Started Masturbating', 'originalTitle': 'Året jag slutade prestera och började onanera', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/48/45/10024845/8045274.$.jpg'}
# 274/4281
# 811327 -> {'title': 'Nimona', 'originalTitle': 'Nimona', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/13/27/811327/8072195.$.jpg'}
# 275/4281
# 842792 -> {'title': 'Babylon', 'originalTitle': 'Babylon', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/27/92/842792/8058426.$.jpg'}
# 276/4281
# 832304 -> {'title': 'Mission: Impossible - Dead Reckoning - Part One', 'originalTitle': 'Mission: Impossible - Dead Reckoning - Part One', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/23/04/832304/8075944.$.jpg'}
# 277/4281
# 10016021 -> {'title': 'Violent Night', 'originalTitle': 'Violent Night', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/60/21/10016021/8055093.$.jpg'}
# 278/4281
# 10014103 -> {'title': 'The Zone of Interest', 'originalTitle': 'The Zone of Interest', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/41/03/10014103/8096351.$.jpg'}
# 279/4281
# 10039592 -> {'title': 'Slotherhouse', 'originalTitle': 'Slotherhouse', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/95/92/10039592/8084555.$.jpg'}
# 280/4281
# 10002852 -> {'title': 'The Killer', 'originalTitle': 'The Killer', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/28/52/10002852/8088116.$.jpg'}
# 281/4281
# 805204 -> {'title': 'Killers of the Flower Moon', 'originalTitle': 'Killers of the Flower Moon', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/52/04/805204/8088427.$.jpg'}
# 282/4281
# 10038878 -> {'title': 'Old Dads', 'originalTitle': 'Old Dads', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/88/78/10038878/8092905.$.jpg'}
# 283/4281
# 10004934 -> {'title': 'She Said', 'originalTitle': 'She Said', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/49/34/10004934/8022151.$.jpg'}
# 284/4281
# 841976 -> {'title': 'How Do You Live?', 'originalTitle': 'Kimi-tachi wa Dō Ikiru ka', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/76/841976/8096460.$.jpg'}
# 285/4281
# 10011892 -> {'title': 'Freestyle', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/18/92/10011892/8091818.$.jpg'}
# 286/4281
# 10000963 -> {'title': 'Life of Crime 1984-2020', 'originalTitle': 'Life of Crime 1984-2020', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/09/63/10000963/7986267.$.jpg'}
# 287/4281
# 832395 -> {'title': "Rifkin's Festival", 'originalTitle': "Rifkin's Festival", 'year': 2020, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/23/95/832395/8102755.$.jpg'}
# 288/4281
# 10026657 -> {'title': 'Talk to Me', 'originalTitle': 'Talk to Me', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/66/57/10026657/8079379.$.jpg'}
# 289/4281
# 10029803 -> {'title': 'Past Lives', 'originalTitle': 'Past Lives', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/98/03/10029803/8094509.$.jpg'}
# 290/4281
# 856901 -> {'title': 'The Banshees of Inisherin', 'originalTitle': 'The Banshees of Inisherin', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/69/01/856901/8054071.$.jpg'}
# 291/4281
# 10003754 -> {'title': 'Beau Is Afraid', 'originalTitle': 'Beau Is Afraid', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/37/54/10003754/8053415.$.jpg'}
# 292/4281
# 10026113 -> {'title': 'Reality', 'originalTitle': 'Reality', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/61/13/10026113/8072664.$.jpg'}
# 293/4281
# 10031406 -> {'title': 'Femme', 'originalTitle': 'Femme', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/14/06/10031406/8059498.$.jpg'}
# 294/4281
# 10002817 -> {'title': 'Oppenheimer', 'originalTitle': 'Oppenheimer', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/28/17/10002817/8071148.$.jpg'}
# 295/4281
# 754800 -> {'title': 'Barbie', 'originalTitle': 'Barbie', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/48/00/754800/8082153.$.jpg'}
# 296/4281
# 10002968 -> {'title': 'No Hard Feelings', 'originalTitle': 'No Hard Feelings', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/29/68/10002968/8088544.$.jpg'}
# 297/4281
# 878158 -> {'title': 'Asteroid City', 'originalTitle': 'Asteroid City', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/81/58/878158/8071093.$.jpg'}
# 298/4281
# 850581 -> {'title': 'The Super Mario Bros. Movie', 'originalTitle': 'The Super Mario Bros. Movie', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/05/81/850581/8095001.$.jpg'}
# 299/4281
# 836056 -> {'title': 'The Little Mermaid', 'originalTitle': 'The Little Mermaid', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/60/56/836056/8084139.$.jpg'}
# 300/4281
# 10011888 -> {'title': "Mother's Day", 'originalTitle': 'Dzień Matki', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/18/88/10011888/8087448.$.jpg'}
# 301/4281
# 877030 -> {'title': 'Fanfic', 'originalTitle': 'Fanfik', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/70/30/877030/8068572.$.jpg'}
# 302/4281
# 10011932 -> {'title': 'Moonage Daydream', 'originalTitle': 'Moonage Daydream', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/32/10011932/8026635.$.jpg'}
# 303/4281
# 10030286 -> {'title': 'Air', 'originalTitle': 'Air', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/02/86/10030286/8059123.$.jpg'}
# 304/4281
# 868026 -> {'title': 'Love, Sex and Pandemic', 'originalTitle': 'Miłość, seks & pandemia', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/80/26/868026/8006130.$.jpg'}
# 305/4281
# 877297 -> {'title': 'Lewandowski - Nieznany', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/72/97/877297/8062625.$.jpg'}
# 306/4281
# 831520 -> {'title': 'John Wick: Chapter 4', 'originalTitle': 'John Wick: Chapter 4', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/15/20/831520/8089380.$.jpg'}
# 307/4281
# 877252 -> {'title': 'Sundown', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/72/52/877252/7993549.$.jpg'}
# 308/4281
# 876373 -> {'title': 'Cocaine Bear', 'originalTitle': 'Cocaine Bear', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/63/73/876373/8058791.$.jpg'}
# 309/4281
# 10011937 -> {'title': 'Holy Spider', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/37/10011937/8014902.$.jpg'}
# 310/4281
# 877594 -> {'title': 'Bread and Salt', 'originalTitle': 'Chleb i sól', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/75/94/877594/8028031.$.jpg'}
# 311/4281
# 10025908 -> {'title': 'Skinamarink', 'originalTitle': 'Skinamarink', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/59/08/10025908/8048718.$.jpg'}
# 312/4281
# 842792 -> {'title': 'Babylon', 'originalTitle': 'Babylon', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/27/92/842792/8058426.$.jpg'}
# 313/4281
# 10006003 -> {'title': 'M3GAN', 'originalTitle': 'M3GAN', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/60/03/10006003/8071277.$.jpg'}
# 314/4281
# 558178 -> {'title': 'Avatar: The Way of Water', 'originalTitle': 'Avatar: The Way of Water', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/81/78/558178/8044395.$.jpg'}
# 315/4281
# 763312 -> {'title': 'The Art of Loving. Story of Michalina Wislocka', 'originalTitle': 'Sztuka kochania. Historia Michaliny Wisłockiej', 'year': 2017, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/33/12/763312/7768931.$.jpg'}
# 316/4281
# 658802 -> {'title': 'Hacksaw Ridge', 'originalTitle': 'Hacksaw Ridge', 'year': 2016, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/88/02/658802/7762627.$.jpg'}
# 317/4281
# 10014103 -> {'title': 'The Zone of Interest', 'originalTitle': 'The Zone of Interest', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/41/03/10014103/8096351.$.jpg'}
# 318/4281
# 825197 -> {'title': 'Rise Roar Revolt', 'originalTitle': 'RRR', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/51/97/825197/7937317.$.jpg'}
# 319/4281
# 125469 -> {'title': 'Bad Night', 'originalTitle': 'Mala Noche', 'year': 1986, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/54/69/125469/7723820.$.jpg'}
# 320/4281
# 10037418 -> {'title': 'Postcards from the Verge', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/74/18/10037418/8091793.$.jpg'}
# 321/4281
# 10010732 -> {'title': 'Girl Gang', 'originalTitle': 'Girl Gang', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/07/32/10010732/8014952.$.jpg'}
# 322/4281
# 10016320 -> {'title': 'You Are So Not Invited to My Bat Mitzvah', 'originalTitle': 'You Are So Not Invited to My Bat Mitzvah', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/63/20/10016320/8085788.$.jpg'}
# 323/4281
# 10026657 -> {'title': 'Talk to Me', 'originalTitle': 'Talk to Me', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/66/57/10026657/8079379.$.jpg'}
# 324/4281
# 10026113 -> {'title': 'Reality', 'originalTitle': 'Reality', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/61/13/10026113/8072664.$.jpg'}
# 325/4281
# 862860 -> {'title': 'The Kid Detective', 'originalTitle': 'The Kid Detective', 'year': 2020, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/28/60/862860/7934744.$.jpg'}
# 326/4281
# 10006656 -> {'title': 'When You Finish Saving the World', 'originalTitle': 'When You Finish Saving the World', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/66/56/10006656/8054760.$.jpg'}
# 327/4281
# 842826 -> {'title': 'Spider-Man: Across the Spider-Verse', 'originalTitle': 'Spider-Man: Across the Spider-Verse', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/28/26/842826/8053460.$.jpg'}
# 328/4281
# 10035218 -> {'title': 'Red, White & Royal Blue', 'originalTitle': 'Red, White & Royal Blue', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/52/18/10035218/8073113.$.jpg'}
# 329/4281
# 114883 -> {'title': 'Lords of Dogtown', 'originalTitle': 'Lords of Dogtown', 'year': 2005, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/48/83/114883/7941417.$.jpg'}
# 330/4281
# 239233 -> {'title': 'Skaterdater', 'originalTitle': 'Skaterdater', 'year': 1965, 'type': 'film', 'subType': 'film_cinema'}
# 331/4281
# 100157 -> {'title': "Thrashin'", 'originalTitle': "Thrashin'", 'year': 1986, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/01/57/100157/7459172.$.jpg'}
# 332/4281
# 35705 -> {'title': 'Il Sorpasso', 'originalTitle': 'Il sorpasso', 'year': 1962, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/57/05/35705/7416888_1.$.jpg'}
# 333/4281
# 816797 -> {'title': 'Sleep Has Her House', 'originalTitle': 'Sleep Has Her House', 'year': 2017, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/67/97/816797/7901237.$.jpg'}
# 334/4281
# 10032046 -> {'title': 'Slow', 'originalTitle': 'Tu man nieko neprimeni', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/20/46/10032046/8082710.$.jpg'}
# 335/4281
# 10034596 -> {'title': 'Inside the Yellow Cocoon Shell', 'originalTitle': 'Bên trong vỏ kén vàng', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/45/96/10034596/8110190.$.jpg'}
# 336/4281
# 874369 -> {'title': 'The Eternal Daughter', 'originalTitle': 'The Eternal Daughter', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/43/69/874369/8046510.$.jpg'}
# 337/4281
# 716526 -> {'title': "'Til Madness Do Us Part", 'originalTitle': 'Feng ai', 'year': 2013, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/65/26/716526/7689922.$.jpg'}
# 338/4281
# 10027281 -> {'title': 'A Thousand and One', 'originalTitle': 'A Thousand and One', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/72/81/10027281/8064808.$.jpg'}
# 339/4281
# 10017369 -> {'title': 'Piaffe', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/73/69/10017369/8089803.$.jpg'}
# 340/4281
# 10008661 -> {'title': 'La chimera', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/86/61/10008661/8097753.$.jpg'}
# 341/4281
# 10011941 -> {'title': 'Showing Up', 'originalTitle': 'Showing Up', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/41/10011941/8047194.$.jpg'}
# 342/4281
# 10034429 -> {'title': 'The Delinquents', 'originalTitle': 'Los delincuentes', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/44/29/10034429/8101613.$.jpg'}
# 343/4281
# 10030785 -> {'title': 'Here', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/07/85/10030785/8057529.$.jpg'}
# 344/4281
# 853936 -> {'title': 'About Dry Grasses', 'originalTitle': 'Kuru Otlar Üstüne', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/39/36/853936/8071549.$.jpg'}
# 345/4281
# 10034331 -> {'title': 'How to Have Sex', 'originalTitle': 'How to Have Sex', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/43/31/10034331/8095519.$.jpg'}
# 346/4281
# 10034333 -> {'title': 'The Passion of Dodin Bouffant', 'originalTitle': 'La passion de Dodin Bouffant', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/43/33/10034333/8105849.$.jpg'}
# 347/4281
# 10032679 -> {'title': 'Monster', 'originalTitle': 'Kaibutsu', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/26/79/10032679/8095842.$.jpg'}
# 348/4281
# 10000129 -> {'title': 'Bad Living', 'originalTitle': 'Mal Viver', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/01/29/10000129/8057732.$.jpg'}
# 349/4281
# 10030847 -> {'title': 'Living Bad', 'originalTitle': 'Viver Mal', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/08/47/10030847/8058206.$.jpg'}
# 350/4281
# 10032055 -> {'title': 'Club Zero', 'originalTitle': 'Club Zero', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/20/55/10032055/8107644.$.jpg'}
# 351/4281
# 10002817 -> {'title': 'Oppenheimer', 'originalTitle': 'Oppenheimer', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/28/17/10002817/8071148.$.jpg'}
# 352/4281
# 754800 -> {'title': 'Barbie', 'originalTitle': 'Barbie', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/48/00/754800/8082153.$.jpg'}
# 353/4281
# 10014595 -> {'title': 'The Secret of Little Rose', 'originalTitle': 'Różyczka 2', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/45/95/10014595/8087312.$.jpg'}
# 354/4281
# 10030846 -> {'title': 'Disco Boy', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/08/46/10030846/8101943.$.jpg'}
# 355/4281
# 10014814 -> {'title': 'Doppelgänger. The Double', 'originalTitle': 'Doppelgänger. Sobowtór', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/48/14/10014814/8085613.$.jpg'}
# 356/4281
# 10039040 -> {'title': 'The Green Border', 'originalTitle': 'Zielona granica', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/90/40/10039040/8102370.$.jpg'}
# 357/4281
# 10030023 -> {'title': 'Limbo', 'originalTitle': 'Limbo', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/00/23/10030023/8057518.$.jpg'}
# 358/4281
# 10016720 -> {'title': 'Saint Omer', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/67/20/10016720/8105544.$.jpg'}
# 359/4281
# 10038612 -> {'title': "Pilecki's Report", 'originalTitle': 'Raport Pileckiego', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/86/12/10038612/8082760.$.jpg'}
# 360/4281
# 10028825 -> {'title': 'Ukryta sieć', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/88/25/10028825/8078773.$.jpg'}
# 361/4281
# 10013518 -> {'title': 'The Beasts', 'originalTitle': 'As bestas', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/35/18/10013518/8089301.$.jpg'}
# 362/4281
# 10026657 -> {'title': 'Talk to Me', 'originalTitle': 'Talk to Me', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/66/57/10026657/8079379.$.jpg'}
# 363/4281
# 10026113 -> {'title': 'Reality', 'originalTitle': 'Reality', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/61/13/10026113/8072664.$.jpg'}
# 364/4281
# 10032747 -> {'title': 'After Work', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/27/47/10032747/8063288.$.jpg'}
# 365/4281
# 10025256 -> {'title': 'Cobweb', 'originalTitle': 'Cobweb', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/52/56/10025256/8087482.$.jpg'}
# 366/4281
# 754800 -> {'title': 'Barbie', 'originalTitle': 'Barbie', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/48/00/754800/8082153.$.jpg'}
# 367/4281
# 10002817 -> {'title': 'Oppenheimer', 'originalTitle': 'Oppenheimer', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/28/17/10002817/8071148.$.jpg'}
# 368/4281
# 832304 -> {'title': 'Mission: Impossible - Dead Reckoning - Part One', 'originalTitle': 'Mission: Impossible - Dead Reckoning - Part One', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/23/04/832304/8075944.$.jpg'}
# 369/4281
# 878158 -> {'title': 'Asteroid City', 'originalTitle': 'Asteroid City', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/81/58/878158/8071093.$.jpg'}
# 370/4281
# 10011949 -> {'title': 'R.M.N.', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/49/10011949/8087723.$.jpg'}
# 371/4281
# 10011934 -> {'title': 'Burning Days', 'originalTitle': 'Kurak Günler', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/34/10011934/8013745.$.jpg'}
# 372/4281
# 527837 -> {'title': 'Indiana Jones 5', 'originalTitle': 'Indiana Jones and the Dial of Destiny', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/78/37/527837/8072665.$.jpg'}
# 373/4281
# 10013416 -> {'title': 'Pamfir', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/34/16/10013416/8067255.$.jpg'}
# 374/4281
# 10028905 -> {'title': 'Leave', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/89/05/10028905/8055900.$.jpg'}
# 375/4281
# 10011939 -> {'title': 'Cairo Conspiracy', 'originalTitle': 'Boy from Heaven', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/39/10011939/8038515.$.jpg'}
# 376/4281
# 10011946 -> {'title': 'Tori and Lokita', 'originalTitle': 'Tori et Lokita', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/46/10011946/8061728.$.jpg'}
# 377/4281
# 806077 -> {'title': 'Guardians of the Galaxy Vol. 3', 'originalTitle': 'Guardians of the Galaxy Vol. 3', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/60/77/806077/8061365.$.jpg'}
# 378/4281
# 869475 -> {'title': 'The Three Musketeers', 'originalTitle': "Les Trois Mousquetaires: D'Artagnan", 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/94/75/869475/8047013.$.jpg'}
# 379/4281
# 876952 -> {'title': 'Evil Dead Rise', 'originalTitle': 'Evil Dead Rise', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/69/52/876952/8075084.$.jpg'}
# 380/4281
# 10003754 -> {'title': 'Beau Is Afraid', 'originalTitle': 'Beau Is Afraid', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/37/54/10003754/8053415.$.jpg'}
# 381/4281
# 751495 -> {'title': 'Chainmail', 'originalTitle': 'Dungeons & Dragons: Honor Among Thieves', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/14/95/751495/8062314.$.jpg'}
# 382/4281
# 10017257 -> {'title': 'The Perfect Number', 'originalTitle': 'Liczba doskonała', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/72/57/10017257/8064226.$.jpg'}
# 383/4281
# 831520 -> {'title': 'John Wick: Chapter 4', 'originalTitle': 'John Wick: Chapter 4', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/15/20/831520/8089380.$.jpg'}
# 384/4281
# 10011944 -> {'title': 'Corsage', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/44/10011944/8053638.$.jpg'}
# 385/4281
# 862867 -> {'title': 'The Decision to Break Up', 'originalTitle': 'Heojil kyolshim', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/28/67/862867/8050365.$.jpg'}
# 386/4281
# 10011953 -> {'title': 'EO', 'originalTitle': 'IO', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/53/10011953/8047437.$.jpg'}
# 387/4281
# 10010778 -> {'title': 'Scream VI', 'originalTitle': 'Scream VI', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/07/78/10010778/8064176.$.jpg'}
# 388/4281
# 10011937 -> {'title': 'Holy Spider', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/37/10011937/8014902.$.jpg'}
# 389/4281
# 10011968 -> {'title': 'Godland', 'originalTitle': 'Vanskabte Land', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/19/68/10011968/8086161.$.jpg'}
# 390/4281
# 877594 -> {'title': 'Bread and Salt', 'originalTitle': 'Chleb i sól', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/75/94/877594/8028031.$.jpg'}
# 391/4281
# 860180 -> {'title': 'Terrifier 2', 'originalTitle': 'Terrifier 2', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/01/80/860180/8056840.$.jpg'}
# 392/4281
# 558178 -> {'title': 'Avatar: The Way of Water', 'originalTitle': 'Avatar: The Way of Water', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/81/78/558178/8044395.$.jpg'}
# 393/4281
# 10013187 -> {'title': 'The Five Devils', 'originalTitle': 'Les cinq diables', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/31/87/10013187/8082281.$.jpg'}
# 394/4281
# 859440 -> {'title': 'Speak No Evil', 'originalTitle': 'Gæsterne', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/94/40/859440/7990342.$.jpg'}
# 395/4281
# 875647 -> {'title': 'The Menu ', 'originalTitle': 'The Menu ', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/56/47/875647/8053539.$.jpg'}
# 396/4281
# 10011887 -> {'title': 'Hellhole', 'originalTitle': 'Ostatnia wieczerza', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/18/87/10011887/8038535.$.jpg'}
# 397/4281
# 10015211 -> {'title': 'Barbarian', 'originalTitle': 'Barbarian', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/52/11/10015211/8019796.$.jpg'}
# 398/4281
# 853834 -> {'title': 'Triangle of Sadness', 'originalTitle': 'Triangle of Sadness', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/38/34/853834/8042146.$.jpg'}
# 399/4281
# 849665 -> {'title': 'The Silent Twins', 'originalTitle': 'Silent Twins', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/96/65/849665/8023355.$.jpg'}
# 400/4281
# 10015510 -> {'title': 'It Came from the Water', 'originalTitle': 'Apokawixa', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/55/10/10015510/8029347.$.jpg'}
# 401/4281
# 10014473 -> {'title': 'The Invitation', 'originalTitle': 'The Invitation', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/44/73/10014473/8046796.$.jpg'}
# 402/4281
# 10015105 -> {'title': 'Smile', 'originalTitle': 'Smile', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/51/05/10015105/8067868.$.jpg'}
# 403/4281
# 876037 -> {'title': 'Operation: Nation', 'originalTitle': 'Kryptonim Polska', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/60/37/876037/8025391.$.jpg'}
# 404/4281
# 836441 -> {'title': 'Thor: Love and Thunder', 'originalTitle': 'Thor: Love and Thunder', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/64/41/836441/8009036.$.jpg'}
# 405/4281
# 869679 -> {'title': 'Nope', 'originalTitle': 'Nope', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/96/79/869679/7967171.$.jpg'}
# 406/4281
# 873373 -> {'title': 'Crimes of the Future', 'originalTitle': 'Crimes of the Future', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/33/73/873373/8040900.$.jpg'}
# 407/4281
# 568942 -> {'title': 'Archipelago', 'originalTitle': 'Archipelago', 'year': 2010, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/89/42/568942/7344923.$.jpg'}
# 408/4281
# 834905 -> {'title': 'After Yang', 'originalTitle': 'After Yang', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/49/05/834905/7999059.$.jpg'}
# 409/4281
# 7117 -> {'title': 'The Exorcism of Emily Rose', 'originalTitle': 'The Exorcism of Emily Rose', 'year': 2005, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/71/17/7117/7540921.$.jpg'}
# 410/4281
# 602101 -> {'title': 'Top Gun: Maverick', 'originalTitle': 'Top Gun: Maverick', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/21/01/602101/8007553.$.jpg'}
# 411/4281
# 869059 -> {'title': 'The Black Phone', 'originalTitle': 'The Black Phone', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/90/59/869059/8068001.$.jpg'}
# 412/4281
# 10004587 -> {'title': 'Madeleine Collins', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/45/87/10004587/7983810.$.jpg'}
# 413/4281
# 853675 -> {'title': 'Everything Everywhere All at Once', 'originalTitle': 'Everything Everywhere All at Once', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/36/75/853675/8026188.$.jpg'}
# 414/4281
# 10007247 -> {'title': 'Men', 'originalTitle': 'Men', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/72/47/10007247/8015070.$.jpg'}
# 415/4281
# 836440 -> {'title': 'Doctor Strange in the Multiverse of Madness', 'originalTitle': 'Doctor Strange in the Multiverse of Madness', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/64/40/836440/8008937.$.jpg'}
# 416/4281
# 10006835 -> {'title': 'X', 'originalTitle': 'X', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/68/35/10006835/8067296.$.jpg'}
# 417/4281
# 841602 -> {'title': 'The Northman', 'originalTitle': 'The Northman', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/16/02/841602/8019678.$.jpg'}
# 418/4281
# 840660 -> {'title': 'The Electrical Life of Louis Wain', 'originalTitle': 'The Electrical Life of Louis Wain', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/06/60/840660/7979344.$.jpg'}
# 419/4281
# 873545 -> {'title': 'Ambulance', 'originalTitle': 'Ambulance', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/35/45/873545/7988393.$.jpg'}
# 420/4281
# 857962 -> {'title': 'The Peasants', 'originalTitle': 'Chłopi', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/79/62/857962/8107908.$.jpg'}
# 421/4281
# 10039040 -> {'title': 'The Green Border', 'originalTitle': 'Zielona granica', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/90/40/10039040/8102370.$.jpg'}
# 422/4281
# 10002817 -> {'title': 'Oppenheimer', 'originalTitle': 'Oppenheimer', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/28/17/10002817/8071148.$.jpg'}
# 423/4281
# 93662 -> {'title': 'Pather Panchali', 'year': 1955, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/36/62/93662/7916608.$.jpg'}
# 424/4281
# 10016728 -> {'title': 'All the Beauty and the Bloodshed', 'originalTitle': 'All the Beauty and the Bloodshed', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/67/28/10016728/8034519.$.jpg'}
# 425/4281
# 806077 -> {'title': 'Guardians of the Galaxy Vol. 3', 'originalTitle': 'Guardians of the Galaxy Vol. 3', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/60/77/806077/8061365.$.jpg'}
# 426/4281
# 10012548 -> {'title': 'Bodies Bodies Bodies', 'originalTitle': 'Bodies Bodies Bodies', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/25/48/10012548/8033122.$.jpg'}
# 427/4281
# 10026657 -> {'title': 'Talk to Me', 'originalTitle': 'Talk to Me', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/66/57/10026657/8079379.$.jpg'}
# 428/4281
# 1508 -> {'title': 'Beijing Summer', 'originalTitle': 'Fa yeung nin wa', 'year': 2000, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/15/08/1508/7491770.$.jpg'}
# 429/4281
# 717784 -> {'title': 'The Ceremony', 'originalTitle': 'La cérémonie', 'year': 2014, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/77/84/717784/7705339.$.jpg'}
# 430/4281
# 343501 -> {'title': 'Romance', 'year': 1999, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/35/01/343501/7220601.$.jpg'}
# 431/4281
# 10016319 -> {'title': 'Rule 34', 'originalTitle': 'Regra 34', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/63/19/10016319/8022941.$.jpg'}
# 432/4281
# 439009 -> {'title': 'Eden and After', 'originalTitle': "L'Éden et après", 'year': 1970, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/90/09/439009/7472335.$.jpg'}
# 433/4281
# 874065 -> {'title': 'The Worst Person in the World', 'originalTitle': 'Verdens verste menneske', 'year': 2021, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/40/65/874065/8019471.$.jpg'}
# 434/4281
# 10032677 -> {'title': 'Fallen Leaves', 'originalTitle': 'Kuolleet lehdet', 'year': 2023, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/26/77/10032677/8095694.$.jpg'}
# 435/4281
# 10016720 -> {'title': 'Saint Omer', 'year': 2022, 'type': 'film', 'subType': 'film_cinema', 'posterPath': '/67/20/10016720/8105544.$.jpg'}
# 436/4281
# ...
# 4200/4281
# 810037 -> {'title': 'Russian Doll', 'originalTitle': 'Russian Doll', 'year': 2019, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/00/37/810037/8009269.$.jpg'}
# 4201/4281
# 809758 -> {'title': 'Sex Education', 'originalTitle': 'Sex Education', 'year': 2019, 'otherYear': 2023, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/97/58/809758/8088800.$.jpg'}
# 4202/4281
# 794594 -> {'title': 'Big Mouth', 'originalTitle': 'Big Mouth', 'year': 2017, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/45/94/794594/7858761.$.jpg'}
# 4203/4281
# 621252 -> {'title': 'Evil Genius', 'originalTitle': 'Evil Genius', 'year': 2018, 'otherYear': 2018, 'type': 'serial', 'subType': 'mini_serial', 'posterPath': '/12/52/621252/7844361.$.jpg'}
# 4204/4281
# 708543 -> {'title': 'Transparent', 'originalTitle': 'Transparent', 'year': 2014, 'otherYear': 2019, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/85/43/708543/7639456.$.jpg'}
# 4205/4281
# 718443 -> {'title': 'BoJack Horseman', 'originalTitle': 'BoJack Horseman', 'year': 2014, 'otherYear': 2020, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/84/43/718443/7978576.$.jpg'}
# 4206/4281
# 792922 -> {'title': 'Za marzenia', 'year': 2018, 'otherYear': 2019, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/29/22/792922/7868752.$.jpg'}
# 4207/4281
# 803155 -> {'title': 'Wild Wild Country', 'originalTitle': 'Wild Wild Country', 'year': 2018, 'otherYear': 2018, 'type': 'serial', 'subType': 'mini_serial', 'posterPath': '/31/55/803155/7830593.$.jpg'}
# 4208/4281
# 792826 -> {'title': 'Money Heist', 'originalTitle': 'La casa de papel', 'year': 2017, 'otherYear': 2021, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/28/26/792826/7969311.$.jpg'}
# 4209/4281
# 769613 -> {'title': 'Altered Carbon', 'originalTitle': 'Altered Carbon', 'year': 2018, 'otherYear': 2020, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/96/13/769613/7823937.$.jpg'}
# 4210/4281
# 747565 -> {'title': "Lemony Snicket's A Series of Unfortunate Events", 'originalTitle': "Lemony Snicket's A Series of Unfortunate Events", 'year': 2017, 'otherYear': 2019, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/75/65/747565/7766125.$.jpg'}
# 4211/4281
# 788999 -> {'title': 'Happy!', 'originalTitle': 'Happy!', 'year': 2017, 'otherYear': 2019, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/89/99/788999/7946509.$.jpg'}
# 4212/4281
# 772652 -> {'title': 'The Tick', 'originalTitle': 'The Tick', 'year': 2016, 'otherYear': 2019, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/26/52/772652/7800315.$.jpg'}
# 4213/4281
# 769619 -> {'title': 'Fleabag', 'originalTitle': 'Fleabag', 'year': 2016, 'otherYear': 2019, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/96/19/769619/7901741.$.jpg'}
# 4214/4281
# 703470 -> {'title': 'Happy Valley', 'originalTitle': 'Happy Valley', 'year': 2014, 'otherYear': 2023, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/34/70/703470/8059894.$.jpg'}
# 4215/4281
# 779550 -> {'title': 'Ozark', 'originalTitle': 'Ozark', 'year': 2017, 'otherYear': 2022, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/95/50/779550/7917081.$.jpg'}
# 4216/4281
# 760310 -> {'title': 'F Is for Family', 'originalTitle': 'F Is for Family', 'year': 2015, 'otherYear': 2021, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/03/10/760310/7753884.$.jpg'}
# 4217/4281
# 765501 -> {'title': 'The Good Place', 'originalTitle': 'The Good Place', 'year': 2016, 'otherYear': 2020, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/55/01/765501/7894875.$.jpg'}
# 4218/4281
# 785070 -> {'title': 'The Orville', 'originalTitle': 'The Orville', 'year': 2017, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/50/70/785070/7969447.$.jpg'}
# 4219/4281
# 792367 -> {'title': 'Neo Yokio', 'originalTitle': 'Neo Yokio', 'year': 2017, 'otherYear': 2017, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/23/67/792367/7803285.$.jpg'}
# 4220/4281
# 138123 -> {'title': 'Azumanga Daioh', 'originalTitle': 'Azumanga Daiō The Animation', 'year': 2002, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/81/23/138123/7821282.$.jpg'}
# 4221/4281
# 787428 -> {'title': 'Castlevania', 'originalTitle': 'Castlevania', 'year': 2017, 'otherYear': 2021, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/74/28/787428/7914219.$.jpg'}
# 4222/4281
# 771634 -> {'title': "The Handmaid's Tale", 'originalTitle': "The Handmaid's Tale", 'year': 2017, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/16/34/771634/7975521.$.jpg'}
# 4223/4281
# 528992 -> {'title': 'Sherlock', 'originalTitle': 'Sherlock', 'year': 2010, 'otherYear': 2017, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/89/92/528992/7720426.$.jpg'}
# 4224/4281
# 227568 -> {'title': 'The Dreamstone', 'originalTitle': 'The Dreamstone', 'year': 1990, 'otherYear': 1995, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/75/68/227568/7039090.$.jpg'}
# 4225/4281
# 640699 -> {'title': 'Black Mirror', 'originalTitle': 'Black Mirror', 'year': 2011, 'type': 'serial', 'subType': 'episode_anthology', 'posterPath': '/06/99/640699/8074599.$.jpg'}
# 4226/4281
# 750828 -> {'title': 'Documentary Now!', 'originalTitle': 'Documentary Now!', 'year': 2015, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/08/28/750828/7716200.$.jpg'}
# 4227/4281
# 735378 -> {'title': 'Baskets', 'originalTitle': 'Baskets', 'year': 2016, 'otherYear': 2019, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/53/78/735378/7720225.$.jpg'}
# 4228/4281
# 767468 -> {'title': 'Atlanta', 'originalTitle': 'Atlanta', 'year': 2016, 'otherYear': 2022, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/74/68/767468/8027747.$.jpg'}
# 4229/4281
# 727710 -> {'title': 'Zoo', 'originalTitle': 'Zoo', 'year': 2015, 'otherYear': 2017, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/77/10/727710/7786852.$.jpg'}
# 4230/4281
# 753764 -> {'title': 'Master of None', 'originalTitle': 'Master of None', 'year': 2015, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/37/64/753764/7713877.$.jpg'}
# 4231/4281
# 37003 -> {'title': 'Twin Peaks', 'originalTitle': 'Twin Peaks', 'year': 1990, 'otherYear': 1991, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/70/03/37003/7964362.$.jpg'}
# 4232/4281
# 750359 -> {'title': 'Stranger Things', 'originalTitle': 'Stranger Things', 'year': 2016, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/03/59/750359/7855603.$.jpg'}
# 4233/4281
# 625092 -> {'title': 'Gravity Falls', 'originalTitle': 'Gravity Falls', 'year': 2012, 'otherYear': 2016, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/50/92/625092/7560007.$.jpg'}
# 4234/4281
# 751258 -> {'title': 'Lady Dynamite', 'originalTitle': 'Lady Dynamite', 'year': 2016, 'otherYear': 2017, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/12/58/751258/7810972.$.jpg'}
# 4235/4281
# Failed for: 436089. Try again in second.
# 4235/4281
# 436089 -> {'title': 'The Life & Times of Tim', 'originalTitle': 'The Life & Times of Tim', 'year': 2008, 'otherYear': 2012, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/60/89/436089/7822143.$.jpg'}
# 4236/4281
# Failed for: 758433. Try again in second.
# 4236/4281
# Failed for: 758433. Try again in second.
# 4236/4281
# 758433 -> {'title': 'Animals.', 'originalTitle': 'Animals.', 'year': 2016, 'otherYear': 2018, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/84/33/758433/7723975.$.jpg'}
# 4237/4281
# 729530 -> {'title': 'The Run of His Life: The People v. O.J. Simpson', 'originalTitle': 'American Crime Story: The People v. O.J. Simpson', 'year': 2016, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/95/30/729530/7786247.$.jpg'}
# 4238/4281
# 651176 -> {'title': 'Derek', 'originalTitle': 'Derek', 'year': 2012, 'otherYear': 2014, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/11/76/651176/7693639.$.jpg'}
# 4239/4281
# 620228 -> {'title': "Life's Too Short", 'originalTitle': "Life's Too Short", 'year': 2011, 'otherYear': 2013, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/02/28/620228/7428946.$.jpg'}
# 4240/4281
# 689702 -> {'title': 'Steven Universe', 'originalTitle': 'Steven Universe', 'year': 2013, 'otherYear': 2019, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/97/02/689702/7734099.$.jpg'}
# 4241/4281
# 728963 -> {'title': 'Over the Garden Wall', 'originalTitle': 'Over the Garden Wall', 'year': 2014, 'otherYear': 2014, 'type': 'serial', 'subType': 'mini_serial', 'posterPath': '/89/63/728963/7670286.$.jpg'}
# 4242/4281
# 559517 -> {'title': 'Louie', 'originalTitle': 'Louie', 'year': 2010, 'otherYear': 2015, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/95/17/559517/7404066.$.jpg'}
# 4243/4281
# 202887 -> {'title': 'The Office', 'originalTitle': 'The Office', 'year': 2005, 'otherYear': 2013, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/28/87/202887/7906640.$.jpg'}
# 4244/4281
# 150481 -> {'title': 'The Office', 'originalTitle': 'The Office', 'year': 2001, 'otherYear': 2003, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/04/81/150481/7997204.$.jpg'}
# 4245/4281
# 735261 -> {'title': 'Catastrophe', 'originalTitle': 'Catastrophe', 'year': 2015, 'otherYear': 2019, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/52/61/735261/7957005.$.jpg'}
# 4246/4281
# 733795 -> {'title': 'Mr. Robot', 'originalTitle': 'Mr. Robot', 'year': 2015, 'otherYear': 2019, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/37/95/733795/7785931.$.jpg'}
# 4247/4281
# 725776 -> {'title': 'Humans', 'originalTitle': 'Humans', 'year': 2015, 'otherYear': 2018, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/57/76/725776/7697707.$.jpg'}
# 4248/4281
# 710930 -> {'title': 'UnREAL', 'originalTitle': 'UnREAL', 'year': 2015, 'otherYear': 2018, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/09/30/710930/7692264.$.jpg'}
# 4249/4281
# 476848 -> {'title': 'A Song of Ice and Fire', 'originalTitle': 'Game of Thrones', 'year': 2011, 'otherYear': 2019, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/68/48/476848/7680989.$.jpg'}
# 4250/4281
# 605700 -> {'title': 'Olive Kitteridge', 'originalTitle': 'Olive Kitteridge', 'year': 2014, 'otherYear': 2014, 'type': 'serial', 'subType': 'mini_serial', 'posterPath': '/57/00/605700/7976103.$.jpg'}
# 4251/4281
# 698665 -> {'title': 'Togetherness', 'originalTitle': 'Togetherness', 'year': 2015, 'otherYear': 2016, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/86/65/698665/7661692.$.jpg'}
# 4252/4281
# 270224 -> {'title': 'Moral Orel', 'originalTitle': 'Moral Orel', 'year': 2005, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/02/24/270224/7544146.$.jpg'}
# 4253/4281
# 10011884 -> {'title': 'Infamy', 'originalTitle': 'Infamia', 'year': 2023, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/18/84/10011884/8086167.$.jpg'}
# 4254/4281
# 860894 -> {'title': 'Warszawianka', 'year': 2023, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/08/94/860894/8071708.$.jpg'}
# 4255/4281
# 640699 -> {'title': 'Black Mirror', 'originalTitle': 'Black Mirror', 'year': 2011, 'type': 'serial', 'subType': 'episode_anthology', 'posterPath': '/06/99/640699/8074599.$.jpg'}
# 4256/4281
# 430668 -> {'title': 'Breaking Bad', 'originalTitle': 'Breaking Bad', 'year': 2008, 'otherYear': 2013, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/06/68/430668/7953039.$.jpg'}
# 4257/4281
# 779456 -> {'title': 'Succession', 'originalTitle': 'Succession', 'year': 2018, 'otherYear': 2023, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/94/56/779456/8019990.$.jpg'}
# 4258/4281
# 10017539 -> {'title': 'Emigracja XD', 'year': 2023, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/75/39/10017539/8059462.$.jpg'}
# 4259/4281
# 849662 -> {'title': 'The Last of Us', 'originalTitle': 'The Last of Us', 'year': 2023, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/96/62/849662/8040046.$.jpg'}
# 4260/4281
# 875491 -> {'title': 'The White Lotus', 'originalTitle': 'The White Lotus', 'year': 2021, 'type': 'serial', 'subType': 'season_anthology', 'posterPath': '/54/91/875491/7964044.$.jpg'}
# 4261/4281
# 876630 -> {'title': 'The Office PL', 'year': 2021, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/66/30/876630/8097563.$.jpg'}
# 4262/4281
# 10014243 -> {'title': 'The Bear', 'originalTitle': 'The Bear', 'year': 2022, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/42/43/10014243/8070114.$.jpg'}
# 4263/4281
# 871816 -> {'title': 'High Water', 'originalTitle': 'Wielka woda', 'year': 2022, 'otherYear': 2022, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/18/16/871816/8065735.$.jpg'}
# 4264/4281
# 750359 -> {'title': 'Stranger Things', 'originalTitle': 'Stranger Things', 'year': 2016, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/03/59/750359/7855603.$.jpg'}
# 4265/4281
# 856019 -> {'title': 'This Is Going To Hurt', 'originalTitle': 'This Is Going To Hurt', 'year': 2022, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/60/19/856019/8018717.$.jpg'}
# 4266/4281
# 810751 -> {'title': 'Euphoria', 'originalTitle': 'Euphoria', 'year': 2019, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/07/51/810751/7991984.$.jpg'}
# 4267/4281
# 10039427 -> {'title': 'Superpowered: The DC Story', 'originalTitle': 'Superpowered: The DC Story', 'year': 2023, 'otherYear': 2023, 'type': 'serial', 'subType': 'mini_serial', 'posterPath': '/94/27/10039427/8082772.$.jpg'}
# 4268/4281
# 878 -> {'title': 'The Kingdom II', 'originalTitle': 'Riget II', 'year': 1997, 'type': 'serial', 'subType': 'mini_serial', 'posterPath': '/08/78/878/7319467.$.jpg'}
# 4269/4281
# 779456 -> {'title': 'Succession', 'originalTitle': 'Succession', 'year': 2018, 'otherYear': 2023, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/94/56/779456/8019990.$.jpg'}
# 4270/4281
# 87721 -> {'title': 'The Wire', 'originalTitle': 'The Wire', 'year': 2002, 'otherYear': 2008, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/77/21/87721/7525375.$.jpg'}
# 4271/4281
# 809681 -> {'title': 'Watchmen', 'originalTitle': 'Watchmen', 'year': 2019, 'otherYear': 2019, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/96/81/809681/7929567.$.jpg'}
# 4272/4281
# 10029957 -> {'title': 'Lucky Hank', 'originalTitle': 'Lucky Hank', 'year': 2023, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/99/57/10029957/8062293.$.jpg'}
# 4273/4281
# 10031643 -> {'title': 'Waco: American Apocalypse', 'originalTitle': 'Waco: American Apocalypse', 'year': 2023, 'otherYear': 2023, 'type': 'serial', 'subType': 'mini_serial', 'posterPath': '/16/43/10031643/8060013.$.jpg'}
# 4274/4281
# 851246 -> {'title': 'Beef', 'originalTitle': 'Beef', 'year': 2023, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/12/46/851246/8063259.$.jpg'}
# 4275/4281
# 10007455 -> {'title': 'Fleishman Is in Trouble', 'originalTitle': 'Fleishman Is in Trouble', 'year': 2022, 'otherYear': 2022, 'type': 'serial', 'subType': 'mini_serial', 'posterPath': '/74/55/10007455/8034024.$.jpg'}
# 4276/4281
# 849662 -> {'title': 'The Last of Us', 'originalTitle': 'The Last of Us', 'year': 2023, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/96/62/849662/8040046.$.jpg'}
# 4277/4281
# 10012801 -> {'title': 'Mo', 'originalTitle': 'Mo', 'year': 2022, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/28/01/10012801/8025620.$.jpg'}
# 4278/4281
# 875491 -> {'title': 'The White Lotus', 'originalTitle': 'The White Lotus', 'year': 2021, 'type': 'serial', 'subType': 'season_anthology', 'posterPath': '/54/91/875491/7964044.$.jpg'}
# 4279/4281
# 877025 -> {'title': 'Reservation Dogs', 'originalTitle': 'Reservation Dogs', 'year': 2021, 'otherYear': 2023, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/70/25/877025/8083503.$.jpg'}
# 4280/4281
# 835082 -> {'title': 'The Lord of the Rings: The Rings of Power', 'originalTitle': 'The Lord of the Rings: The Rings of Power', 'year': 2022, 'type': 'serial', 'subType': 'serial_tv', 'posterPath': '/50/82/835082/8033650.$.jpg'}

# %%
columns = ['show_id', 'title']
mapped_df = pd.DataFrame(mapped,columns=columns)
mapped_df
# Out:
#        show_id                                      title
# 0     10014103                       The Zone of Interest
# 1     10025735                                   Passages
# 2       805204                 Killers of the Flower Moon
# 3     10034333               La passion de Dodin Bouffant
# 4     10015490                                   Imaculat
# ...        ...                                        ...
# 4276    849662                             The Last of Us
# 4277  10012801                                         Mo
# 4278    875491                            The White Lotus
# 4279    877025                           Reservation Dogs
# 4280    835082  The Lord of the Rings: The Rings of Power
#
# [4281 rows x 2 columns]

# %%
merge = pd.merge(df_dataset, mapped_df, on='show_id', how='outer').drop_duplicates()
merge.to_csv("../dataset/dataset_with_titles.csv", encoding='utf-8', sep='$', index=False)
merge.to_json("../dataset/dataset_with_titles.json")

# %% [markdown]
# # New dataset cases

# %%
shows_df = pd.read_csv('../dataset/dataset.csv', encoding='utf-8', sep='$')
shows_df
# Out:
#              username   show_id  user_rate  \
# 0     michaloleszczyk  10014103          8
# 1     michaloleszczyk  10025735          3
# 2     michaloleszczyk    805204          9
# 3     michaloleszczyk  10034333          9
# 4     michaloleszczyk  10015490          9
# ...               ...       ...        ...
# 4276       alekhudzik    849662          3
# 4277       alekhudzik  10012801          6
# 4278       alekhudzik    875491          7
# 4279       alekhudzik    877025         10
# 4280       alekhudzik    835082         10
#
#                                            user_comment  show_rating  \
# 0     Willa Hössa jako makieta najciemniejszej stron...      8.32095
# 1     Zgentryfikowana "Mama i dziwka" o smaku pumpki...      6.41777
# 2     "Ile wilków widzisz na obrazku?" A ile widzisz...      7.41684
# 3     Film bliski perfekcji; czysty i syty jak ronde...      7.36086
# 4     Wielka niespodzianka i najbardziej oryginalny ...      5.44533
# ...                                                 ...          ...
# 4276  O wow. Nie udało się zekranizować gry komputer...      7.77990
# 4277  No takie ten. "1 świat 3 świat", kalejdoskop p...      6.79320
# 4278        Dwójka lepsza od jedynki. Zamykamy dyskusję      7.67484
# 4279  Jest to najlepszy serial "Coming of age" świat...      7.22280
# 4280  LEPSZE OD PETERA JACKSONA bo a) więcej kasy b)...      5.19931
#
#       show_rating_count       type
# 0                   296      movie
# 1                   833      movie
# 2                  9884      movie
# 3                   557      movie
# 4                   375      movie
# ...                 ...        ...
# 4276              58245  tv_series
# 4277                353  tv_series
# 4278              40515  tv_series
# 4279                579  tv_series
# 4280              28057  tv_series
#
# [4281 rows x 7 columns]

# %%
shows_df = pd.read_csv('../dataset/dataset_with_titles.csv', encoding='utf-8', sep='$')
shows = list(shows_df[['title', 'show_id']].drop_duplicates().to_records(index=False))

# %%
shows
# Out:
# [('The Zone of Interest', 10014103),
#  ('Passages', 10025735),
#  ('Killers of the Flower Moon', 805204),
#  ('La passion de Dodin Bouffant', 10034333),
#  ('Imaculat', 10015490),
#  ('Saw X', 10017756),
#  ('Saint Omer', 10016720),
#  ('Carmen', 10020792),
#  ('El Conde', 10035212),
#  ('La donna della domenica', 7043),
#  ('A Haunting in Venice', 10021659),
#  ('Past Lives', 10029803),
#  ('Chien Blanc', 10040235),
#  ('Marcel the Shell with Shoes On', 10011754),
#  ('Red, White & Royal Blue', 10035218),
#  ('No Hard Feelings', 10002968),
#  ('Les cinq diables', 10013187),
#  ('The Last Voyage of Demeter', 562230),
#  ('Gran Turismo', 10014818),
#  ('Palm Trees and Power Lines', 10006316),
#  ('Reality', 10026113),
#  ('Pamfir', 10013416),
#  ('Strays', 10019458),
#  ('Talk to Me', 10026657),
#  ('The Night of the Generals', 37242),
#  ('Dialóg 20-40-60', 5040),
#  ('The Seven-Per-Cent Solution', 10863),
#  ('Thampu', 281473),
#  ('Szürkület', 448632),
#  ('Longford', 402521),
#  ('Oppenheimer', 10002817),
#  ('Club Zero', 10032055),
#  ('Aranyer Din Ratri', 115937),
#  ('Kuru Otlar Üstüne', 853936),
#  ('Khers nist', 10016727),
#  ('Barbie', 754800),
#  ('Indiana Jones and the Dial of Destiny', 527837),
#  ('Asteroid City', 878158),
#  ('My Neighbor Adolf', 10015793),
#  ('Spider-Man: Across the Spider-Verse', 842826),
#  ('The Little Mermaid', 836056),
#  ('Beau Is Afraid', 10003754),
#  ('Evil Dead Rise', 876952),
#  ('Brainwashed: Sex-Camera-Power', 10006436),
#  ('Tár', 10016709),
#  ('John Wick: Chapter 4', 831520),
#  ('Tinker Tailor Soldier Spy', 575916),
#  ('Scream VI', 10010778),
#  ('Creed III', 870583),
#  ('The Whale', 868478),
#  ('Titanic', 187),
#  ('Close', 10009831),
#  ('All That Breathes', 10007213),
#  ('Skinamarink', 10025908),
#  ("Magic Mike's Last Dance", 10024087),
#  ('Heojil kyolshim', 862867),
#  ('Knock at the Cabin', 10003038),
#  ('Aftersun', 10013300),
#  ('The Lost City', 868024),
#  ('Znachor', 10030489),
#  ('Lęk', 10015096),
#  ('Kos', 870175),
#  ('Imago', 872645),
#  ('Święto ognia', 10022197),
#  ('Freestyle', 10011892),
#  ('Jedna dusza', 10008680),
#  ('Figurant', 10014053),
#  ('Horror Story', 10039707),
#  ('Tyle co nic', 10039004),
#  ('Chłopi', 857962),
#  ('Fin del mundo?', 10039003),
#  ('Doppelgänger. Sobowtór', 10014814),
#  ('Święty', 10023575),
#  ('Zielona granica', 10039040),
#  ('O psie, który jeździł koleją', 10017555),
#  ('Mon crime', 10029389),
#  ('Competencia oficial', 856775),
#  ('Sound of Freedom', 849551),
#  ('Dziewczyny z Dubaju®', 847757),
#  ('Pan Samochodzik i templariusze', 10011894),
#  ('Mission: Impossible - Dead Reckoning - Part One', 832304),
#  ('The Unlikely Pilgrimage of Harold Fry', 10030620),
#  ('Boylesque', 10011354),
#  ('Le bleu du caftan', 10013183),
#  ('En los márgenes', 10016756),
#  ('Dalíland', 10020096),
#  ('Peter von Kant', 10006841),
#  ("L'immensità", 10013971),
#  ('Brigitte Bardot cudowna', 835074),
#  ('Lewandowski - Nieznany', 877297),
#  ('RRR', 825197),
#  ('Filip', 10015975),
#  ('Empire of Light', 10018057),
#  ('Les Amandiers', 10011936),
#  ('Syk pike', 10011964),
#  ('The Banshees of Inisherin', 856901),
#  ('Niebezpieczni dżentelmeni', 875018),
#  ('Babylon', 842792),
#  ('Noc w przedszkolu', 10011890),
#  ('Till', 10016690),
#  ('The Fabelmans', 877306),
#  ('Glass Onion: A Knives Out Mystery', 876242),
#  ('Avatar: The Way of Water', 558178),
#  ('Triangle of Sadness', 853834),
#  ('The Wonder', 10010480),
#  ('Alcarràs', 10000405),
#  ('Beurokeo', 859404),
#  ('Blonde', 576938),
#  ('Broad Peak', 812176),
#  ('Silent Twins', 849665),
#  ('IO', 10011953),
#  ('Chleb i sól', 877594),
#  ('Strzępy', 10015974),
#  ('Głupcy', 863370),
#  ('Śubuk', 867491),
#  ('Johnny', 847549),
#  ('Orzeł. Ostatni patrol', 794006),
#  ('Orlęta. Grodno ‘39', 863851),
#  ('Vortex', 876284),
#  ('Niezwykła podróż Baltazara Kobera', 8124),
#  ('Kryptonim Polska', 876037),
#  ('Irréductible', 10000284),
#  ('The Gray Man', 856965),
#  ('Persuasion', 868984),
#  ('Good Luck to You, Leo Grande', 10006528),
#  ('Elvis', 856764),
#  ('Jurassic World Dominion', 804059),
#  ('The Electrical Life of Louis Wain', 840660),
#  ('Top Gun: Maverick', 602101),
#  ('The Northman', 841602),
#  ('The Batman', 626318),
#  ('Everything Everywhere All at Once', 853675),
#  ('Saint Maud', 840945),
#  ('Scarface', 32442),
#  ('Turn Every Page - The Adventures of Robert Caro and Robert Gottlieb', 10030857),
#  ('Shirasagi', 123246),
#  ('Die Sehnsucht der Veronika Voss', 97264),
#  ('Lynch/Oz', 10014861),
#  ('The Great Escape', 11669),
#  ('Nope', 869679),
#  ('Love Me Tonight', 164870),
#  ('Desert Hearts', 116122),
#  ('Nightmare Alley', 848506),
#  ('Trouble in Paradise', 35873),
#  ('No Time to Die', 757778),
#  ('My Psychedelic Love Story', 854562),
#  ('Mandibules', 843227),
#  ('Titane', 181137),
#  ("Can't Stop the Music", 31120),
#  ('Angst', 3879),
#  ('Różyczka 2', 10014595),
#  ('Ukryta sieć', 10028825),
#  ('Operacja: Soulcatcher', 10033068),
#  ('Love Actually', 99390),
#  ('Dzień Matki', 10011888),
#  ('Rój', 857111),
#  ('Fanfik', 877030),
#  ('Perpetrator', 10031530),
#  ('Kuolleet lehdet', 10032677),
#  ('Medusa Deluxe', 10015819),
#  ('The Eternal Daughter', 874369),
#  ('La vaca que cantó una canción sobre el futuro', 10006328),
#  ('Polite Society', 10029379),
#  ('They Cloned Tyrone', 10020866),
#  ('Femme', 10031406),
#  ('Scrapper', 10031611),
#  ('Rapito', 10034186),
#  ('Orlando, ma biographie politique', 10029801),
#  ('The Menu ', 875647),
#  ('How to Have Sex', 10034331),
#  ('Silver Haze', 10026114),
#  ('Blue Jean', 10019146),
#  ('Guardians of the Galaxy Vol. 3', 806077),
#  ('She Said', 10004934),
#  ('All the Beauty and the Bloodshed', 10016728),
#  ('Roving Woman', 10017590),
#  ('An Cailín Ciúin', 10008865),
#  ('Pianoforte', 10025744),
#  ('Norwegian Dream', 10019378),
#  ('Women Talking', 10014388),
#  ('Rye Lane', 10026510),
#  ('Nanny', 10006435),
#  ('Drive My Car', 875490),
#  ("C'mon C'mon", 850352),
#  ('The Woman King', 10012484),
#  ('Sundown', 877252),
#  ('Große Freiheit', 875575),
#  ('Red Rocket', 870351),
#  ('Turning Red', 866841),
#  ('Crimes of the Future', 873373),
#  ('Słoń', 10012675),
#  ('Corsage', 10011944),
#  ('Klondike', 10006285),
#  ('Catherine Called Birdy', 10013507),
#  ('Córki dancingu', 727844),
#  ('Eternals', 836119),
#  ('Vera andrron detin', 10000816),
#  ('Në kërkim të Venerës', 10012203),
#  ('Luaneshat e kodrës', 863273),
#  ('Flux Gourmet', 10007593),
#  ('Vidblysk', 877300),
#  ('Exil', 849076),
#  ('Terrifier 2', 860180),
#  ('Heat', 660),
#  ("The Pope's Exorcist", 10019202),
#  ('Poison', 10041757),
#  ('Sicario: Day of the Soldado', 776171),
#  ('Roadrunner: A Film About Anthony Bourdain', 875498),
#  ('WALL·E', 399328),
#  ('Jalsaghar', 197782),
#  ('Aparajito', 93660),
#  ('Nayak', 115926),
#  ('Charulata', 115929),
#  ('Jeanne Dielman, 23 Quai du Commerce, 1080 Bruxelles', 182521),
#  ('After', 10031648),
#  ('Pather Panchali', 93662),
#  ('Wake in Fright', 121115),
#  ('Inside', 10024515),
#  ('Operation Fortune: Ruse de guerre', 868880),
#  ('Blut & Gold', 10034267),
#  ('Banshun', 111954),
#  ('Hellraiser', 10014838),
#  ('Året jag slutade prestera och började onanera', 10024845),
#  ('Nimona', 811327),
#  ('Violent Night', 10016021),
#  ('Slotherhouse', 10039592),
#  ('The Killer', 10002852),
#  ('Old Dads', 10038878),
#  ('Kimi-tachi wa Dō Ikiru ka', 841976),
#  ('Life of Crime 1984-2020', 10000963),
#  ("Rifkin's Festival", 832395),
#  ('The Super Mario Bros. Movie', 850581),
#  ('Moonage Daydream', 10011932),
#  ('Air', 10030286),
#  ('Miłość, seks & pandemia', 868026),
#  ('Cocaine Bear', 876373),
#  ('Holy Spider', 10011937),
#  ('M3GAN', 10006003),
#  ('Sztuka kochania. Historia Michaliny Wisłockiej', 763312),
#  ('Hacksaw Ridge', 658802),
#  ('Mala Noche', 125469),
#  ('Postcards from the Verge', 10037418),
#  ('Girl Gang', 10010732),
#  ('You Are So Not Invited to My Bat Mitzvah', 10016320),
#  ('The Kid Detective', 862860),
#  ('When You Finish Saving the World', 10006656),
#  ('Lords of Dogtown', 114883),
#  ('Skaterdater', 239233),
#  ("Thrashin'", 100157),
#  ('Il sorpasso', 35705),
#  ('Sleep Has Her House', 816797),
#  ('Tu man nieko neprimeni', 10032046),
#  ('Bên trong vỏ kén vàng', 10034596),
#  ('Feng ai', 716526),
#  ('A Thousand and One', 10027281),
#  ('Piaffe', 10017369),
#  ('La chimera', 10008661),
#  ('Showing Up', 10011941),
#  ('Los delincuentes', 10034429),
#  ('Here', 10030785),
#  ('Kaibutsu', 10032679),
#  ('Mal Viver', 10000129),
#  ('Viver Mal', 10030847),
#  ('Disco Boy', 10030846),
#  ('Limbo', 10030023),
#  ('Raport Pileckiego', 10038612),
#  ('As bestas', 10013518),
#  ('After Work', 10032747),
#  ('Cobweb', 10025256),
#  ('R.M.N.', 10011949),
#  ('Kurak Günler', 10011934),
#  ('Leave', 10028905),
#  ('Boy from Heaven', 10011939),
#  ('Tori et Lokita', 10011946),
#  ("Les Trois Mousquetaires: D'Artagnan", 869475),
#  ('Dungeons & Dragons: Honor Among Thieves', 751495),
#  ('Liczba doskonała', 10017257),
#  ('Vanskabte Land', 10011968),
#  ('Gæsterne', 859440),
#  ('Ostatnia wieczerza', 10011887),
#  ('Barbarian', 10015211),
#  ('Apokawixa', 10015510),
#  ('The Invitation', 10014473),
#  ('Smile', 10015105),
#  ('Thor: Love and Thunder', 836441),
#  ('Archipelago', 568942),
#  ('After Yang', 834905),
#  ('The Exorcism of Emily Rose', 7117),
#  ('The Black Phone', 869059),
#  ('Madeleine Collins', 10004587),
#  ('Men', 10007247),
#  ('Doctor Strange in the Multiverse of Madness', 836440),
#  ('X', 10006835),
#  ('Ambulance', 873545),
#  ('Bodies Bodies Bodies', 10012548),
#  ('Fa yeung nin wa', 1508),
#  ('La cérémonie', 717784),
#  ('Romance', 343501),
#  ('Regra 34', 10016319),
#  ("L'Éden et après", 439009),
#  ('Verdens verste menneske', 874065),
#  ('Tótem', 10030351),
#  ('It Happened One Night', 31784),
#  ('Koński ogon', 10036578),
#  ('Perfect Days', 10034351),
#  ('Braty', 866235),
#  ('Gräns', 807678),
#  ('Pokolenie Ikea', 10018322),
#  ("L'Événement", 877251),
#  ('Chung hing sam lam', 511),
#  ('Klute', 1299),
#  ('Jakoś to będzie', 849364),
#  ('Annette', 786279),
#  ('The French Dispatch', 817418),
#  ('Gūzen to Sōzō', 869422),
#  ('Licorice Pizza', 868631),
#  ('Dýrið', 875522),
#  ('Malignant', 840348),
#  ('El buen patrón', 10000314),
#  ("Don't Look Up", 848823),
#  ('Enfant Terrible', 848763),
#  ('The Suicide Squad', 751753),
#  ('The Power of the Dog', 837523),
#  ('House', 130394),
#  ('Wszystkie nasze strachy', 876866),
#  ('Dune', 469476),
#  ('Żeby nie było śladów', 853563),
#  ('Wesele', 857506),
#  ('Retfærdighedens ryttere', 857935),
#  ('Candyman', 32204),
#  ('Candyman', 815907),
#  ('Lux Æterna', 837886),
#  ('Zola', 849119),
#  ('Blutsauger', 869707),
#  ('Aladdin', 790398),
#  ('Onward', 832178),
#  ('Soul', 836650),
#  ('Puss in Boots: The Last Wish', 714479),
#  ('Inside the Mind of a Cat', 10016781),
#  ('Za duży na bajki', 10002949),
#  ('Tytöt tytöt tytöt', 10006318),
#  ('Marry Me', 852253),
#  ('Spencer', 856136),
#  ('Queen Elizabeth II: The Diamond Celebration', 10003252),
#  ('Hiacynt', 871821),
#  ('Teściowie', 875819),
#  ('Made in Italy', 854974),
#  ('Takiego pięknego syna urodziłam', 114454),
#  ('Sweat', 855109),
#  ("Billie Eilish: The World's a Little Blurry", 862167),
#  ('Tourist Trap', 40563),
#  ('Curfew', 133606),
#  ('Akelarre', 859198),
#  ('Muere, monstruo, muere', 813109),
#  ('Cuando acecha la maldad', 10041299),
#  ('It Lives Inside', 10031857),
#  ('The Shuttered Room', 192522),
#  ('Them!', 34468),
#  ('Anvil! The Story of Anvil', 468378),
#  ('Night Life', 96600),
#  ('Terms of Endearment', 1022),
#  ('The Royal Hotel', 10039880),
#  ('Terror Train', 10108),
#  ('Motel Hell', 126735),
#  ('Prom Night', 4033),
#  ('Hermana Muerte', 876513),
#  ("Five Nights at Freddy's", 739524),
#  ('As Good as It Gets', 97),
#  ('84 Charing Cross Road', 3509),
#  ('Reptile', 10031941),
#  ("In My Mother's Skin", 10027987),
#  ('Fair Play', 10026692),
#  ('The Eiger Sanction', 10328),
#  ('The Color of Money', 1280),
#  ('The Exorcist: Believer', 877700),
#  ('The Hustler', 10472),
#  ('Cat Person', 10003088),
#  ('Konferensen', 10041692),
#  ('Dark Harvest', 10012830),
#  ('Stepfather III', 115505),
#  ('Saw', 121413),
#  ('Invasion of Privacy', 34295),
#  ('Payback', 132073),
#  ('Lady Beware', 38590),
#  ('Hellraiser III: Hell on Earth', 34715),
#  ('Hellraiser: Bloodline', 34742),
#  ('The Fugitive', 1233),
#  ('Shoot the Moon', 34932),
#  ('Rumble Fish', 36819),
#  ('Totally Killer', 10040488),
#  ('Mrs. Soffel', 7898),
#  ('Pet Sematary: Bloodlines', 878157),
#  ('Dominion: Prequel to the Exorcist', 196247),
#  ('The Equalizer 3', 10012260),
#  ('Looking for Mr. Goodbar', 7403),
#  ('Falling in Love', 5523),
#  ('Ghoulies', 88273),
#  ('Frenzy', 1322),
#  ("Coal Miner's Daughter", 4689),
#  ('Changing Lanes', 32367),
#  ('No One Will Save You', 10040970),
#  ('Expend4bles', 701578),
#  ('The Seven-Ups', 36595),
#  ('Slaughterhouse', 121801),
#  ('McCabe & Mrs. Miller', 7633),
#  ('Znachor', 1175),
#  ('Smokey and the Bandit', 7763),
#  ('Bride of the Monster', 108603),
#  ('The Nun II', 833087),
#  ('Images', 6382),
#  ('Teściowie 2', 10021076),
#  ('Godzilla vs. Kong', 750312),
#  ('Prêt-à-Porter', 8873),
#  ('Fast Times at Ridgemont High', 34088),
#  ('High Plains Drifter', 6147),
#  ('Elemental', 10019714),
#  ('Fletch', 5637),
#  ('Fled', 12076),
#  ('Retribution', 10038269),
#  ("God's Country", 10006851),
#  ('I Spit on Your Grave 3', 739876),
#  ('I Spit on Your Grave 2', 669681),
#  ('I Spit on Your Grave', 544183),
#  ('Day of the Woman', 120958),
#  ('Karakter', 24),
#  ('Beetle Juice', 9641),
#  ('W nich cała nadzieja', 10039013),
#  ('Zemlya', 91319),
#  ('Natural Born Killers', 1049),
#  ('2001: A Space Odyssey', 1458),
#  ('Blue Beetle', 869944),
#  ('Poker Face', 10012715),
#  ('892', 876666),
#  ('Teenage Mutant Ninja Turtles: Mutant Mayhem', 10032160),
#  ('Goodfellas', 1033),
#  ("Guy Ritchie's The Covenant", 10003640),
#  ("Les filles d'Olfa", 10034339),
#  ('Man in Black', 10036094),
#  ('Film annonce du film qui n\'existera jamais: "Drôles de Guerres"', 10036484),
#  ('Enys Men', 10013110),
#  ('Modelo 77', 10017759),
#  ('Extraction 2', 10002123),
#  ('Wham!', 10036059),
#  ('Enter the Dragon', 11580),
#  ('Edward Scissorhands', 5355),
#  ('Ed Wood', 5347),
#  ('Transformers: Rise of the Beasts', 790781),
#  ('The Flash', 219794),
#  ('Wielka droga', 36469),
#  ('Gladiator', 936),
#  ('The Thin Red Line', 28),
#  ('The Ghost of Richard Harris', 10017956),
#  ('Maigret', 10010319),
#  ('Peter Pan & Wendy', 771873),
#  ('The Naked Gun: From the Files of Police Squad!', 30762),
#  ('Sisu', 10020122),
#  ('Solaris mon amour', 10033771),
#  ('Superman', 9881),
#  ('Beast', 862321),
#  ('Per una bara piena di dollari', 118806),
#  ('La noire de...', 126263),
#  ('Suzume no Tojimari', 10011868),
#  ('Ekstase', 414927),
#  ('Jiabiangou', 584421),
#  ('San Zimei', 662388),
#  ('Il buco', 872148),
#  ('Wyrwa', 10012444),
#  ('Zadra', 10006049),
#  ('Masz ci los!', 10015919),
#  ('Matecznik', 866644),
#  ('À plein temps', 10000907),
#  ('Anatomia', 10002138),
#  ('Lombard', 10011431),
#  ('Ghahreman', 875479),
#  ('Iluzja', 10006484),
#  ('Cicha ziemia', 877911),
#  ('Detektyw Bruno', 874214),
#  ('Fucking Bornholm', 875426),
#  ('Film balkonowy', 877376),
#  ('Piosenki o miłości', 876884),
#  ('Sonata', 860594),
#  ('The Lost Daughter', 852533),
#  ('Belfast', 866220),
#  ('Madres paralelas', 859971),
#  ('The Card Counter', 856079),
#  ('Magdalena', 876885),
#  ('Memoria', 826447),
#  ('Inni ludzie', 837100),
#  ('Spider-Man: No Way Home', 850261),
#  ('Scream', 851885),
#  ('West Side Story', 830546),
#  ('House of Gucci', 866641),
#  ('Ucieczka na Srebrny Glob', 877706),
#  ('Nuevo Orden', 857594),
#  ('Pleasure', 855103),
#  ('Halloween Kills', 838819),
#  ('Furioza', 833810),
#  ('Moje wspaniałe życie', 874469),
#  ('Babardeală cu bucluc sau porno balamuc', 869415),
#  ('Magnezja', 838035),
#  ('Czarna owca', 865320),
#  ('Petite maman', 864445),
#  ('Najmro. Kocha, kradnie, szanuje', 836649),
#  ('Bo we mnie jest seks', 836323),
#  ('Nobody', 840078),
#  ('Black Widow', 120986),
#  ('Wrath of Man', 850377),
#  ('The Father', 835469),
#  ('Czarne słońca', 1173),
#  ('The Creator', 10020414),
#  ('Pearl', 10016719),
#  ('Nashville', 8026),
#  ('Priscilla', 10020076),
#  ("Finalmente l'alba", 10017849),
#  ('Poor Things', 874687),
#  ('Comandante', 10039415),
#  ('Zima', 10035863),
#  ('Moje stare', 10033712),
#  ('Crazy Heart', 490840),
#  ('Warrior', 499338),
#  ('The Pale Blue Eye', 870411),
#  ('Stutz', 10022217),
#  ('The Last Duel', 842133),
#  ('War Dogs', 731322),
#  ('Downfall: The Case Against Boeing', 10007295),
#  ('J’accuse', 655158),
#  ('The Matrix Resurrections', 838524),
#  ('Red Notice', 829539),
#  ('Prey', 10006906),
#  ('Ford v Ferrari', 705791),
#  ('Damage', 9577),
#  ('Tom Jones', 8959),
#  ('About My Father', 10025670),
#  ('Profondo rosso', 37601),
#  ('Crows Are White', 10034704),
#  ('Anselm – Das Rauschen der Zeit', 10035507),
#  ('Roter Himmel', 10029838),
#  ('Descending the Mountain', 10012993),
#  ('All That Jazz', 1293),
#  ('Tourment sur les îles', 10013179),
#  ('Supernova', 836062),
#  ('Frantic', 1107),
#  ('Bitter Moon', 1108),
#  ('Happy People: A Year in the Taiga', 587332),
#  ('La panthère des neiges', 877071),
#  ('Coming to America', 6916),
#  ('Burden of Dreams', 34927),
#  ('Fitzcarraldo', 31610),
#  ('Knight of Cups', 638866),
#  ('The Boy, the Mole, the Fox and the Horse', 10025909),
#  ('Amsterdam', 868629),
#  ('The General', 34200),
#  ("Il sol dell'avvenire", 10033766),
#  ('Heart of Stone', 868727),
#  ('French Kiss', 5711),
#  ('Sommaren med Monika', 31701),
#  ('Raiders of the Lost Ark', 1216),
#  ('Bullitt', 4376),
#  ('Leto kada sam naučila da letim', 10015963),
#  ('Alla vita', 10017351),
#  ('W Centrum Komiksu', 855760),
#  ('Lucy in the Sky', 817419),
#  ('Innocence', 10016850),
#  ('The Pledge', 10746),
#  ('The Longest Goodbye', 10031589),
#  ('Myši patří do nebe', 720145),
#  ('When Harry Met Sally...', 1266),
#  ('Jeanne du Barry', 10028214),
#  ('Robot Dreams', 10036102),
#  ('Linda veut du poulet !', 10036313),
#  ('McQueen', 740626),
#  ('Lekcja miłości', 856784),
#  ('Mistrz', 843930),
#  ('The Mole: Undercover in North Korea', 865196),
#  ('Capital in the Twenty-First Century', 839839),
#  ('The King of Comedy', 6876),
#  ('Piłsudski', 812540),
#  ('Egoiści', 1078),
#  ("Jennifer's Body", 472475),
#  ("The Pervert's Guide to Cinema", 365206),
#  ('The Thin Blue Line', 162012),
#  ('Opening Night', 38892),
#  ('Grease', 5933),
#  ('Infinity Pool', 876096),
#  ('Killer Joe', 603315),
#  ('Network', 35352),
#  ('Bad Lieutenant', 1062),
#  ('Something Wild', 5310),
#  ('King of New York', 6756),
#  ('Matter Out of Place', 10016300),
#  ('Shrek', 9509),
#  ('The Square', 786678),
#  ('Good Will Hunting', 21),
#  ('Xi You', 707248),
#  ('Ser ser salhi', 10039496),
#  ('Poszukiwany, poszukiwana', 1169),
#  ('Lousy Carter', 10038748),
#  ('Hot Summer Nights', 747973),
#  ('Topâzu', 99668),
#  ('Luce et le Rocher', 10009251),
#  ('Non si sevizia un paperino', 95052),
#  ('Wedding Crashers', 118129),
#  ('Chillerama', 605456),
#  ('Herstory', 10036471),
#  ('Dzień dobry, dzieci', 290011),
#  ('Echo', 10041432),
#  ('Sorority House Massacre II', 161441),
#  ('The Internship', 655221),
#  ('Meet the Fockers', 109483),
#  ('Joy Ride', 10032033),
#  ('Meet the Parents', 1430),
#  ('fur', 10033091),
#  ('Moje żyjątko', 10037392),
#  ('Safari Club', 10037377),
#  ('Stwór', 10022002),
#  ('Do raju', 10039005),
#  ('Nun or Never', 10041438),
#  ('Noisetrain', 10035864),
#  ('Starsza pani szuka', 10034254),
#  ('Disc+Dog', 10038871),
#  ('Ferrari', 10008279),
#  ('Scream 3', 1081),
#  ('Portrait of Gina', 120701),
#  ('Nie lubię poniedziałku', 901),
#  ('The Lunchbox', 665908),
#  ('Yin ji kau', 124948),
#  ('Mission: Impossible II', 938),
#  ('Mission: Impossible III', 95742),
#  ('The Expendables', 311443),
#  ('Arrête avec tes mensonges', 10019338),
#  ('Human Flowers of Flesh', 10016299),
#  ('Samsara', 10030625),
#  ('Secaderos', 10033195),
#  ('Stille Liv', 10031678),
#  ('Izgubljena zemlja', 10034268),
#  ('The Feeling That the Time for Doing Something Has Passed', 10036077),
#  ('Rewind & Play', 10009513),
#  ('Terra que marca', 10009511),
#  ('Voice', 10038611),
#  ('Eureka', 10034909),
#  ('Sanatorium pod klepsydrą', 9352),
#  ('The Long Goodbye', 5325),
#  ('The Nest', 845655),
#  ('Rodéo', 10011963),
#  ('Dial M for Murder', 7474),
#  ('Primer', 108799),
#  ('Zack and Miri Make a Porno', 447667),
#  ('Crank', 264772),
#  ('Novaya Moskva', 341714),
#  ('Suddenly, Last Summer', 31522),
#  ('The Guilt Trip', 613601),
#  ('Somebody', 723481),
#  ('In Fabric', 815368),
#  ('Cruising', 4744),
#  ('Sur l’Adamant', 10029961),
#  ('Fantastyczny Matt Parey', 10034673),
#  ('Coup de Chance', 10033894),
#  ('Sny pełne dymu', 10032945),
#  ('Da hong deng long gao gao gua', 31273),
#  ('Amazing Grace', 817423),
#  ('Houria', 10013969),
#  ("Anatomie d'une chute", 10032723),
#  ('Toni Erdmann', 763048),
#  ('Qing chun (Chun)', 10034334),
#  ('Perdidos en la noche', 10034265),
#  ('Skąd dokąd', 10034252),
#  ('Simple comme Sylvain', 10034340),
#  ('Rosalie', 10034343),
#  ('Black Flies', 870019),
#  ('War Pony', 10011955),
#  ('Hallelujah: Leonard Cohen, A Journey, A Song', 10000981),
#  ('Tonia', 10015674),
#  ('Le otto montagne', 10013427),
#  ('Shazam! Fury of the Gods', 845693),
#  ("Le Petit Nicolas - Qu'est-ce qu'on attend pour être heureux ?", 10013458),
#  ('Taurus', 10008375),
#  ('Eraserhead', 1088),
#  ('The Amazing Maurice', 10019452),
#  ('Les Olympiades', 875506),
#  ('White Noise', 868630),
#  ('Emily the Criminal', 10006527),
#  ('Nyad', 870334),
#  ('The Souvenir: Part II', 809134),
#  ('Where Is Anne Frank', 830888),
#  ('Cow', 875584),
#  ("Tout s'est bien passé", 875512),
#  ('Mass', 869040),
#  ('On the Count of Three', 868285),
#  ('Passing', 848014),
#  ('Writing with Fire', 868385),
#  ('Zgjoi', 868565),
#  ('Flugt', 855137),
#  ('CODA', 868390),
#  ('The Disciple', 858017),
#  ('Pieces of a Woman', 854517),
#  ('The World to Come', 835189),
#  ('One Night in Miami...', 857959),
#  ('The Duke', 852258),
#  ('Notturno', 819148),
#  ('Nowhere Special', 858526),
#  ('Ema', 834265),
#  ('Honeyland', 816104),
#  ('365 dni', 842452),
#  ('W lesie dziś nie zaśnie nikt', 842425),
#  ('The Burnt Orange Heresy', 537908),
#  ('What Is Life Worth', 821913),
#  ('Shirley', 836659),
#  ('Promising Young Woman', 835486),
#  ('Jojo Rabbit', 817417),
#  ('Proxima', 809002),
#  ('Judy', 823141),
#  ('Cats', 824422),
#  ('The Little Things', 853600),
#  ('Mr. No Legs', 200039),
#  ('The 30 Foot Bride of Candy Rock', 125893),
#  ('15 Cameras', 10041467),
#  ('Grave Encounters', 610178),
#  ('Pumpkinhead II: Blood Wings', 34837),
#  ('Duan jian wu qing', 637617),
#  ('Hung kuen dai see', 463009),
#  ('Jack-O', 153003),
#  ('Trap Jazz', 10040220),
#  ('CB4', 30691),
#  ('Above the Rim', 3682),
#  ('Young Man with a Horn', 11871),
#  ('Shadows', 31849),
#  ('The Devil Wears Prada', 250272),
#  ('All Fun and Games', 10031567),
#  ('Blue Chips', 4260),
#  ('Xue fu rong', 157776),
#  ('Wu yi bian fu', 163982),
#  ('Hard Ball', 6049),
#  ('DNA', 32792),
#  ('Til Death Do Us Part', 10037267),
#  ('Where the Day Takes You', 11622),
#  ('My Animal', 10026439),
#  ('San shao ye de jian', 163991),
#  ('Ying zi shen bian', 142394),
#  ('The Boogeyman', 10029792),
#  ('Santo contra Blue Demon en la Atlántida', 207033),
#  ('Wu lin feng yun', 440854),
#  ('Haunting of the Queen Mary', 10021728),
#  ('Necronomicon', 110361),
#  ('Apt Pupil', 31130),
#  ('Terror at Tenkiller', 481769),
#  ('Hansel and Gretel: Witch Hunters', 520860),
#  ('Deadline', 486560),
#  ('Whisper', 214414),
#  ('Carriers', 337366),
#  ('Red Eye', 147688),
#  ("I'll Always Know What You Did Last Summer", 237829),
#  ('Bad Meat', 637786),
#  ('Bad Girls from Mars', 100321),
#  ('Strange Days', 648),
#  ('The Haunting in Connecticut', 282920),
#  ('Martin', 37642),
#  ('The Fearway', 10010705),
#  ('Wrong Turn 2: Dead End', 325047),
#  ('Club Dread', 38603),
#  ('Dark Ride', 173739),
#  ('The Hoot Owl', 10034290),
#  ('Honky Holocaust', 712620),
#  ("Auntie Lee's Meat Pies", 39587),
#  ('Cabin Fever: Patient Zero', 649019),
#  ('Daughter', 10028488),
#  ('Survival of the Dead', 469828),
#  ('Tamara', 119090),
#  ('Cursed', 98347),
#  ('One Way Passage', 126872),
#  ('A Bill of Divorcement', 31517),
#  ('The Old Dark House', 119575),
#  ("Smilin' Through", 88393),
#  ('Movie Crazy', 121707),
#  ('The Most Dangerous Game', 160182),
#  ('Blonde Venus', 39536),
#  ('Grand Hotel', 34311),
#  ('Back Street', 92015),
#  ('American Madness', 116815),
#  ('Bird of Paradise', 91513),
#  ('Merrily We Go to Hell', 126005),
#  ('Week-end Marriage', 113480),
#  ('Red-Headed Woman', 37654),
#  ('What Price Hollywood?', 35059),
#  ('The Dark Horse', 109635),
#  ('Café Society', 742862),
#  ('Sex Tape', 638531),
#  ('Under the Silver Lake', 775006),
#  ('Jumanji: Welcome to the Jungle', 717250),
#  ('Fast X', 763722),
#  ('F9', 772936),
#  ('Ślub doskonały', 10005155),
#  ('Niewidzialna wojna', 10008125),
#  ('The Mother', 10020683),
#  ('Still: A Michael J. Fox Movie', 10032403),
#  ('Tetris', 876121),
#  ('Sharper', 10015546),
#  ('Black Panther: Wakanda Forever', 837929),
#  ('Ravenous', 30956),
#  ('Django Unchained', 620541),
#  ('Werewolf by Night', 10019753),
#  ('The Harder They Fall', 848270),
#  ('Boyhood', 629125),
#  ('King Richard', 847034),
#  ('The Magnificent Seven', 662836),
#  ('Shang-Chi and the Legend of the Ten Rings', 698547),
#  ('Oxygen', 861020),
#  ('The Hunt', 823512),
#  ('Birds of Prey (And the Fantabulous Emancipation of One Harley Quinn)', 812823),
#  ('Shazam!', 271514),
#  ("Zack Snyder's Justice League", 859126),
#  ('Moxie', 869135),
#  ('Palm Springs', 839586),
#  ('The Map of Tiny Perfect Things', 848637),
#  ('Borat Subsequent Moviefilm', 862168),
#  ('21 Bridges', 829691),
#  (' The Devil All the Time', 809318),
#  ('Alien: Covenant', 665400),
#  ('Interstellar', 375629),
#  ('Tenet', 831653),
#  ('The Old Guard', 843004),
#  ('Pájaros de verano', 807682),
#  ('Extraction', 829070),
#  ('The Palace', 873411),
#  ('The Wonderful Story of Henry Sugar', 10039424),
#  ('Bastarden', 10013944),
#  ('Grbavica', 289277),
#  ('A Bigger Splash', 726089),
#  ('Druk', 838872),
#  ('Richard Jewell', 708511),
#  ('Joker', 810167),
#  ('Systemsprenger', 823221),
#  ('The Loved Ones', 539449),
#  ('Renfield', 877674),
#  ('Deep Water', 843611),
#  ('Lights Out', 750437),
#  ('Synchronic', 827061),
#  ('Do Revenge', 10016444),
#  ('Occhiali neri', 856685),
#  ('Showgirls', 9508),
#  ('Deadly Weapons', 179762),
#  ('Censor', 868290),
#  ('Kilenc hónap', 6740),
#  ('A Woman Under the Influence', 105724),
#  ('An American Werewolf in London', 3831),
#  ('Nowhere', 10040485),
#  ('Falcon Lake', 10013354),
#  ('The Conductor', 10037749),
#  ('Punch', 10025254),
#  ('Paradise', 10033885),
#  ('From Black', 874344),
#  ('Il primo giorno della mia vita', 803734),
#  ('Mimořádná událost', 10012990),
#  ('Champions', 10025566),
#  ('65', 10005986),
#  ('Weird: The Al Yankovic Story', 10007142),
#  ('Plan 75', 10011962),
#  ('Lynx', 877707),
#  ('Noise', 155681),
#  ('Gil-bok-soon', 10009174),
#  ('Deus', 10002307),
#  ('Poslije zime', 876674),
#  ('La ligne', 10007165),
#  ('La nuit du 12', 10013515),
#  ('I Love My Dad', 10012969),
#  ('Vlastníci', 838275),
#  ('Lunana: A Yak in the Classroom', 842841),
#  ('Risen', 876950),
#  ("Devil's Workshop", 10020067),
#  ('Last Survivors', 873503),
#  ('Rimini', 10007161),
#  ('The Retaliators', 870899),
#  ("A Jazzman's Blues", 10018164),
#  ('The Immaculate Room', 10016187),
#  ('Robe of Gems', 10007169),
#  ('Fall', 10014573),
#  ('Samaritan', 840342),
#  ('Event Horizon', 559),
#  ('Gone in the Night', 10011656),
#  ('The Twin', 10008911),
#  ('Character', 875760),
#  ('Resurrection', 10006529),
#  ('Bull', 865946),
#  ('The Night House', 838734),
#  ('Watcher', 10006386),
#  ('She Will', 877591),
#  ("Viens, je t'emmène", 10008674),
#  ('Ninjababy', 870338),
#  ('Amparo', 875898),
#  ('The Perfection', 825998),
#  ('Mid-Century', 139871),
#  ('The Good Neighbor', 10013510),
#  ('El hoyo en la cerca', 10000914),
#  ('Coming Home in the Dark', 868986),
#  ('All My Friends Hate Me', 10004282),
#  ('The Feast', 875420),
#  ('Hustle', 10008947),
#  ('Interceptor', 10009630),
#  ('Room 203', 10011811),
#  ('The Deep House', 855277),
#  ('Father Stu', 10008365),
#  ('Veneciafrenia', 872317),
#  ('North Hollywood', 853072),
#  ('Cube', 869132),
#  ('The Boy Behind the Door', 875690),
#  ('The Bunker Game', 10007345),
#  ('Drive All Night', 870412),
#  ('The Cellar', 10010604),
#  ('Miało cię nie być', 10014774),
#  ('Once Upon a Studio', 10042780),
#  ('Błazny', 10041524),
#  ('Bottoms', 10014400),
#  ('The Ratcatcher', 10041756),
#  ('The Swan', 10041755),
#  ('Ultima Thule', 10031539),
#  ('Życie w błocie się złoci', 10025124),
#  ('Kajtek Czarodziej', 10034666),
#  ('Thais', 10117),
#  ('Lubię nietoperze', 7451),
#  ('Widziadło', 11655),
#  ('Wyjście awaryjne', 974),
#  ('Wilczyca', 11697),
#  ('Opowieść Harleya', 8397),
#  ('Przeklęte oko proroka', 94599),
#  ('Oko proroka', 8314),
#  ('Miłość z listy przebojów', 7779),
#  ('Pierścień i róża', 8649),
#  ('Synteza', 9938),
#  ('Alchemik', 3754),
#  ('Na srebrnym globie', 1138),
#  ('Czułe miejsca', 4816),
#  ('Porady na zdrady 2', 10018060),
#  ('Porady na zdrady', 767724),
#  ('The Survival of Kindness', 10030080),
#  ('Lipstick on the Glass', 849470),
#  ('Tiger Stripes', 10035229),
#  ('Wyspa złoczyńców', 11825),
#  ('Pan Samochodzik i niesamowity dwór', 8511),
#  ('Indiana Jones and the Kingdom of the Crystal Skull', 33392),
#  ('Indiana Jones and the Temple of Doom', 1214),
#  ('Biały smok', 4171),
#  ('Memory', 10013720),
#  ('Hors-saison', 10039414),
#  ('Die Theorie von Allem', 10039420),
#  ('Maestro', 843956),
#  ('Tatami', 10039495),
#  ('Curve', 433986),
#  ('Where the Crawdads Sing', 873851),
#  ('Czekaj na mnie we śnie', 10038115),
#  ('Jediný zatracený přání', 10038613),
#  ('4 Psy', 10014560),
#  ("L'homme qui ment", 105070),
#  ('Savvusanna sõsarad', 10031860),
#  ('Moja siostra', 10036432),
#  ('Extraña forma de vida', 10015380),
#  ('Firebrand', 10010373),
#  ('Le retour', 10034900),
#  ('Le règne animal', 10034344),
#  ("We're the Millers", 152844),
#  ('Prisoners', 507169),
#  ('Misconduct', 741304),
#  ('The Miracle Club', 10034430),
#  ('Meg 2: The Trench', 10010261),
#  ('Nostalgia', 10011952),
#  ('Bliscy', 859219),
#  ('Winnie-The-Pooh: Blood and Honey', 10019127),
#  ('The Son', 10016730),
#  ('The Loneliest Boy in the World', 10019380),
#  ('Biały potok', 847263),
#  ('Tata', 878072),
#  ('Wrobiony', 734419),
#  ('Notre-Dame brûle', 10005882),
#  ('PTU', 136805),
#  ('Don’t Worry Darling', 853784),
#  ('Każdy wie lepiej', 10002753),
#  ('Bullet Train', 856701),
#  ('Nitram', 875508),
#  ('Lightyear', 866839),
#  ('Gold', 866252),
#  ('Fantastic Beasts: The Secrets of Dumbledore', 731997),
#  ('Uncharted', 545895),
#  ('Death on the Nile', 803486),
#  ('Moonfall', 778153),
#  ('The Eyes of Tammy Faye', 844550),
#  ('The Tragedy of Macbeth', 851975),
#  ('Gierek', 856945),
#  ('Jak pokochałam gangstera', 871817),
#  ('Powrót do tamtych dni', 876864),
#  ('Sheytan vojud nadarad', 848370),
#  ('Venom: Let There Be Carnage', 836519),
#  ('Przejście', 876865),
#  ('Śmierć Zygielbojma', 839855),
#  ('The Pigeon Tunnel', 10040903),
#  ('Captain America II: Death Too Soon', 141739),
#  ('Captain America', 188059),
#  ('Puss in Boots', 219972),
#  ('Hidden Strike', 801191),
#  ('Arcydzieło czyli dekalog producenta filmowego', 10034877),
#  ('Stan Lee', 10027675),
#  ('Quasi', 10033007),
#  ("Sergio Leone - L'italiano che inventò l'America", 10017938),
#  ...]

# %%
def get_range(movie_id):
    response = filmweb.get_movie_info(movie_id).json()
    movie_path = f'{quote(response["title"])}-{response["year"]}-{id}'
    content = filmweb.get_movie_discussion(movie_path).text

    soup = BeautifulSoup(content, 'html.parser')

    pages = soup.select("li.pagination__item:has(a[href])")
    pages = list(map(lambda page: page.find('a', class_='pagination__link').get_text(strip=True), pages))
    def map_to_nums(value):
        try:
            result = int(value)
            return result
        except ValueError:
            return None

    pages = list(map(map_to_nums, pages))
    pages = list(filter(lambda x: x is not None, pages))
    start = 1
    if len(pages) < 2:
        end = start
    else:
        end = max(pages)
    return (start, end, movie_path)


def get_discussion_page(movie_path, page):
    content = filmweb.get_movie_discussion(movie_path, page=page).text
    soup = BeautifulSoup(content, 'html.parser')
    result = []
    matching_divs = soup.select('div.forumTopic')
    only_with_starts_comments = [div for div in matching_divs if div.select_one('.forumTopic__starsNo') is not None]

    for div in only_with_starts_comments:
        forum_text = div.select_one('p.forumTopic__text')
        if forum_text:
            text_content = forum_text.get_text(strip=True)
        else:
            text_content = None

        forum_stars = div.select_one('span.forumTopic__starsNo')
        if forum_text:
            stars_content = int(forum_stars.get_text(strip=True))
        else:
            stars_content = None
        result.append((text_content, stars_content))
    return list(filter(lambda x: x[0] is not None and x[1] is not None, result))

# %%
result = []

# %%
from time import sleep
counter = 50
while counter < len(shows):
    movie = shows[counter]
    id = movie[1]
    try:
        start, end, movie_path = get_range(id)
        comments = []
        page = start
        while page < end + 1:
            try:
                print(f"Counter: {counter}/{len(shows)}; ID: {id}; page: {page}")
                comments += get_discussion_page(movie_path, page)
                page += 1
            except:
                print("Failed to get comments from the page. Trying again in 1 second...")
                sleep(1)
        
        result += list(map(lambda c: (movie[0], movie[1], c[0], c[1]), comments))
        counter+=1
    except Exception as e:
        print(f"Failed gathering comments from film: {id} {shows[counter][0]}. Trying again in 1 second... {e}")
        sleep(1)
# Out:
# Counter: 50/2049; ID: 187; page: 1
# Counter: 50/2049; ID: 187; page: 2
# Counter: 50/2049; ID: 187; page: 3
# Counter: 50/2049; ID: 187; page: 4
# Counter: 50/2049; ID: 187; page: 5
# Counter: 50/2049; ID: 187; page: 6
# Counter: 50/2049; ID: 187; page: 7
# Counter: 50/2049; ID: 187; page: 8
# Counter: 50/2049; ID: 187; page: 9
# Counter: 50/2049; ID: 187; page: 10
# Counter: 50/2049; ID: 187; page: 11
# Counter: 50/2049; ID: 187; page: 12
# Counter: 50/2049; ID: 187; page: 13
# Counter: 50/2049; ID: 187; page: 14
# Counter: 50/2049; ID: 187; page: 15
# Counter: 50/2049; ID: 187; page: 16
# Counter: 50/2049; ID: 187; page: 17
# Counter: 50/2049; ID: 187; page: 18
# Counter: 50/2049; ID: 187; page: 19
# Counter: 50/2049; ID: 187; page: 20
# Counter: 50/2049; ID: 187; page: 21
# Counter: 50/2049; ID: 187; page: 22
# Counter: 50/2049; ID: 187; page: 23
# Counter: 50/2049; ID: 187; page: 24
# Counter: 50/2049; ID: 187; page: 25
# Counter: 50/2049; ID: 187; page: 26
# Counter: 50/2049; ID: 187; page: 27
# Counter: 50/2049; ID: 187; page: 28
# Counter: 50/2049; ID: 187; page: 29
# Counter: 50/2049; ID: 187; page: 30
# Counter: 2028/2049; ID: 138123; page: 1
# Counter: 2029/2049; ID: 787428; page: 1
# Counter: 2029/2049; ID: 787428; page: 2
# Counter: 2029/2049; ID: 787428; page: 3
# Counter: 2030/2049; ID: 227568; page: 1
# Counter: 2031/2049; ID: 750828; page: 1
# Counter: 2032/2049; ID: 735378; page: 1
# Counter: 2033/2049; ID: 727710; page: 1
# Counter: 2033/2049; ID: 727710; page: 2
# Counter: 2033/2049; ID: 727710; page: 3
# Counter: 2034/2049; ID: 625092; page: 1
# Counter: 2034/2049; ID: 625092; page: 2
# Counter: 2034/2049; ID: 625092; page: 3
# Counter: 2034/2049; ID: 625092; page: 4
# Counter: 2034/2049; ID: 625092; page: 5
# Counter: 2034/2049; ID: 625092; page: 6
# Counter: 2034/2049; ID: 625092; page: 7
# Counter: 2034/2049; ID: 625092; page: 8
# Counter: 2035/2049; ID: 751258; page: 1
# Counter: 2036/2049; ID: 436089; page: 1
# Counter: 2037/2049; ID: 758433; page: 1
# Counter: 2038/2049; ID: 651176; page: 1
# Counter: 2039/2049; ID: 620228; page: 1
# Counter: 2040/2049; ID: 689702; page: 1
# Counter: 2041/2049; ID: 728963; page: 1
# Counter: 2042/2049; ID: 150481; page: 1
# Counter: 2043/2049; ID: 735261; page: 1
# Counter: 2044/2049; ID: 725776; page: 1
# Counter: 2044/2049; ID: 725776; page: 2
# Counter: 2044/2049; ID: 725776; page: 3
# Counter: 2044/2049; ID: 725776; page: 4
# Counter: 2044/2049; ID: 725776; page: 5
# Counter: 2045/2049; ID: 698665; page: 1
# Counter: 2046/2049; ID: 270224; page: 1
# Counter: 2047/2049; ID: 10039427; page: 1
# Counter: 2048/2049; ID: 10031643; page: 1

# %%
comments_df = pd.DataFrame(result, columns=['title', 'show_id', 'user_comment', 'user_rate']).drop_duplicates().drop(columns=['title'])
comments_df.to_json('./user_comments.json')
comments_df.to_csv('./user_comments.csv', sep='$', encoding='utf-8', index=False)

# %%
dataset_base = shows_df[['show_id', 'show_rating', 'show_rating_count', 'type', 'title']]

# %%
from urllib.parse import urlparse

extend = pd.merge(dataset_base, comments_df, on='show_id').drop_duplicates()
extend['username'] = 'anonymous'
extend = extend[extend['user_comment'].str.len() > 15]

def is_url(string):
    try:
        result = urlparse(string)
        return all([result.scheme, result.netloc])
    except ValueError:
        return False

url_filter = ~extend['user_comment'].apply(is_url)
extend = extend[url_filter]
extend
# Out:
#          show_id  show_rating  show_rating_count       type  \
# 0       10014103      8.32095                296      movie
# 1       10014103      8.32095                296      movie
# 2       10014103      8.32095                296      movie
# 3       10014103      8.32095                296      movie
# 4       10014103      8.32095                296      movie
# ...          ...          ...                ...        ...
# 323277    698665      7.23548               1911  tv_series
# 323278    270224      8.11299                177  tv_series
# 323279  10031643      6.43458                856  tv_series
# 323280  10031643      6.43458                856  tv_series
# 323281  10031643      6.43458                856  tv_series
#
#                             title  \
# 0            The Zone of Interest
# 1            The Zone of Interest
# 2            The Zone of Interest
# 3            The Zone of Interest
# 4            The Zone of Interest
# ...                           ...
# 323277               Togetherness
# 323278                 Moral Orel
# 323279  Waco: American Apocalypse
# 323280  Waco: American Apocalypse
# 323281  Waco: American Apocalypse
#
#                                              user_comment  user_rate  \
# 0       Film niewątpliwie bardzo mocny, świetne zagran...          9
# 1       Czy Strefa interesów naprawdę tak wiele wnosi ...          7
# 2       Dwanaście lat temu Lars von Trier wywołał na f...          8
# 3       filmie? A weź że się się zdecyduj. Czy niedopo...          7
# 4       Żal dupę ściska i robi co w jego mocy. Ale ani...          6
# ...                                                   ...        ...
# 323277                           gdyby nie cycki byłoby 4          5
# 323278  Serial opowiada o Orelu, który, chcąc być dobr...          6
# 323279  Dokument wykonany w sposób dość rzetelny. Podo...          7
# 323280  Naprawdę dorośli ludzie, którzy im ulegają teg...          5
# 323281  Trochę brakuje odcięcia się, skrytykowania lub...          6
#
#          username
# 0       anonymous
# 1       anonymous
# 2       anonymous
# 3       anonymous
# 4       anonymous
# ...           ...
# 323277  anonymous
# 323278  anonymous
# 323279  anonymous
# 323280  anonymous
# 323281  anonymous
#
# [112410 rows x 8 columns]

# %%
base = pd.read_csv('../dataset/dataset_with_titles.csv', encoding='utf-8', sep='$')
base
# Out:
#                  username   show_id  user_rate  \
# 0         michaloleszczyk  10014103          8
# 1         jack_sobczynski  10014103          8
# 2                    Igi3  10014103          9
# 3              no_face_no  10014103          9
# 4     Maciej_Niedzwiedzki  10014103          9
# ...                   ...       ...        ...
# 4276              dem3000    725776          4
# 4277              dem3000    698665          8
# 4278              dem3000    270224          8
# 4279            MCh092788  10039427          5
# 4280           alekhudzik  10031643          8
#
#                                            user_comment  show_rating  \
# 0     Willa Hössa jako makieta najciemniejszej stron...      8.32095
# 1     Wielkie kino o odwracaniu oczu od zła. „To nie...      8.32095
# 2     Potężny masyw obrazu i dźwięku do rozrywania n...      8.32095
# 3     Niesłychana siła wyparcia przedstawiona w bana...      8.32095
# 4     Coś niespotykanego. Całkowicie nowe i niebanal...      8.32095
# ...                                                 ...          ...
# 4276  [ep1-6] Schematyczny dramat, który wstępnie pr...      7.36279
# 4277  Każda postać jest tu bardzo ludzka, pełna wad ...      7.23548
# 4278  Choć seria jest zabawna i celna, wszystkie te ...      8.11299
# 4279  Bardziej reklama dla potencjalnych nowych właś...      6.82828
# 4280  92, Roodney King, 93, Waco. Świetnie pokazana ...      6.43458
#
#       show_rating_count       type                       title
# 0                   296      movie        The Zone of Interest
# 1                   296      movie        The Zone of Interest
# 2                   296      movie        The Zone of Interest
# 3                   296      movie        The Zone of Interest
# 4                   296      movie        The Zone of Interest
# ...                 ...        ...                         ...
# 4276               7718  tv_series                      Humans
# 4277               1911  tv_series                Togetherness
# 4278                177  tv_series                  Moral Orel
# 4279                 99  tv_series  Superpowered: The DC Story
# 4280                856  tv_series   Waco: American Apocalypse
#
# [4281 rows x 8 columns]

# %%
extended_dataset = pd.concat([base, extend], ignore_index=True)
extended_dataset.to_csv('../dataset/extended_dataset.csv', index=False, sep='$', encoding='utf-8')
extended_dataset.to_json('../dataset/extended_dataset.json')

# %%
extended_dataset.groupby('title').count().sort_values(by='username', ascending=False)
# Out:
#                                                username  show_id  user_rate  \
# title
# Avatar                                             3539     3539       3539
# Game of Thrones                                    3535     3535       3535
# The Dark Knight                                    1733     1733       1733
# The Shawshank Redemption                           1398     1398       1398
# Breaking Bad                                       1301     1301       1301
# ...                                                 ...      ...        ...
# Chien Blanc                                           1        1          1
# La vaca que cantó una canción sobre el futuro         1        1          1
# Til Death Do Us Part                                  1        1          1
# Shirasagi                                             1        1          1
# She Will                                              1        1          1
#
#                                                user_comment  show_rating  \
# title
# Avatar                                                 3539         3539
# Game of Thrones                                        3535         3535
# The Dark Knight                                        1733         1733
# The Shawshank Redemption                               1398         1398
# Breaking Bad                                           1301         1301
# ...                                                     ...          ...
# Chien Blanc                                               1            1
# La vaca que cantó una canción sobre el futuro             1            1
# Til Death Do Us Part                                      1            1
# Shirasagi                                                 1            1
# She Will                                                  1            1
#
#                                                show_rating_count  type
# title
# Avatar                                                      3539  3539
# Game of Thrones                                             3535  3535
# The Dark Knight                                             1733  1733
# The Shawshank Redemption                                    1398  1398
# Breaking Bad                                                1301  1301
# ...                                                          ...   ...
# Chien Blanc                                                    1     1
# La vaca que cantó una canción sobre el futuro                  1     1
# Til Death Do Us Part                                           1     1
# Shirasagi                                                      1     1
# She Will                                                       1     1
#
# [2039 rows x 7 columns]

# %%
extended_dataset[extended_dataset['title'] == 'The Shawshank Redemption']
# Out:
#         username  show_id  user_rate  \
# 2973   MCh092788     1048          7
# 74896  anonymous     1048         10
# 74897  anonymous     1048         10
# 74898  anonymous     1048          6
# 74899  anonymous     1048         10
# ...          ...      ...        ...
# 76288  anonymous     1048         10
# 76289  anonymous     1048          6
# 76290  anonymous     1048          4
# 76291  anonymous     1048          5
# 76292  anonymous     1048         10
#
#                                             user_comment  show_rating  \
# 2973   Masterpiece feel good movie. Inkluzywne dzieło...      8.79138
# 74896  zawsze się go dobrze ogląda. Jeden z moich ulu...      8.79138
# 74897  Mam pytanie. Na końcu filmu pojawia się inform...      8.79138
# 74898  Według mnie to na pewno pierwsze miejsce powin...      8.79138
# 74899  Obowiązkowa pozycja każdego kinomana. W tym fi...      8.79138
# ...                                                  ...          ...
# 76288  S.King opowiadanie S.NA SHAWSHANK napisał w ro...      8.79138
# 76289  Nie był najgorszy, ale strasznie się wlekł ......      8.79138
# 76290  Film ok ale bez przesady... zresztą filmwebowy...      8.79138
# 76291                Ujdzie na raz, obejrzeć i zapomnieć      8.79138
# 76292  polecam "Cztery pory roku" Kinga.Nie mówię, ze...      8.79138
#
#        show_rating_count   type                     title
# 2973              914705  movie  The Shawshank Redemption
# 74896             914705  movie  The Shawshank Redemption
# 74897             914705  movie  The Shawshank Redemption
# 74898             914705  movie  The Shawshank Redemption
# 74899             914705  movie  The Shawshank Redemption
# ...                  ...    ...                       ...
# 76288             914705  movie  The Shawshank Redemption
# 76289             914705  movie  The Shawshank Redemption
# 76290             914705  movie  The Shawshank Redemption
# 76291             914705  movie  The Shawshank Redemption
# 76292             914705  movie  The Shawshank Redemption
#
# [1398 rows x 8 columns]
